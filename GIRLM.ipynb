# %%
#GLRLM or Gray Level Run Length Matrix
#33 different features are extracted from this

import matplotlib.pyplot as plt 
from PIL import Image 
import numpy as np
from itertools import groupby

data = 0 
def read_img(path=" "):
        
        try:
            img = Image.open(path) 
            img = img.convert('L')
            self.data=np.array(img)
            
        except:
            img = None
            
def getGrayLevelRumatrix(array, theta):

            
            #array: the numpy array of the image
            #theta: Input, the angle used when calculating the gray scale run matrix, list type, can contain fields:['deg0', 'deg45', 'deg90', 'deg135']
            #glrlm: output,the glrlm result

            P = array
            x, y = P.shape
            min_pixels = np.min(P)   # the min pixel
            run_length = max(x, y)   # Maximum parade length in pixels
            num_level = np.max(P) - np.min(P) + 1   # Image gray level
    
            deg0 = [val.tolist() for sublist in np.vsplit(P, x) for val in sublist]   # 0deg
            deg90 = [val.tolist() for sublist in np.split(np.transpose(P), y) for val in sublist]   # 90deg
            diags = [P[::-1, :].diagonal(i) for i in range(-P.shape[0]+1, P.shape[1])]   #45deg
            deg45 = [n.tolist() for n in diags]
            Pt = np.rot90(P, 3)   # 135deg
            diags = [Pt[::-1, :].diagonal(i) for i in range(-Pt.shape[0]+1, Pt.shape[1])]
            deg135 = [n.tolist() for n in diags]
    
            def length(l):
                if hasattr(l, '_len_'):
                    return np.size(l)
                else:
                    i = 0
                    for _ in l:
                        i += 1
                    return i
    
            glrlm = np.zeros((num_level, run_length, len(theta)))   
            for angle in theta:
                for splitvec in range(0, len(eval(angle))):
                    flattened = eval(angle)[splitvec]
                    answer = []
                    for key, iter in groupby(flattened):  
                        answer.append((key, length(iter)))   
                    for ansIndex in range(0, len(answer)):
                        glrlm[int(answer[ansIndex][0]-min_pixels), int(answer[ansIndex][1]-1), theta.index(angle)] += 1   
            return glrlm

 # The gray scale run matrix is only the measurement and statistics of the image pixel information. In the actual use process, the generated
  #   The gray scale run matrix is calculated to obtain image feature information based on the gray level co-occurrence matrix.
  #   First write a few common functions to complete the calculation of subscripts i and j (calcuteIJ ()), multiply and divide according to the specified dimension (apply_over_degree ())
   #  And calculate the sum of all pixels (calcuteS ())
        
            
def apply_over_degree(function, x1, x2):
        rows, cols, nums = x1.shape
        result = np.ndarray((rows, cols, nums))
        for i in range(nums):
                #print(x1[:, :, i])
                result[:, :, i] = function(x1[:, :, i], x2)
               # print(result[:, :, i])
                result[result == np.inf] = 0
                result[np.isnan(result)] = 0
        return result 
def calcuteIJ (rlmatrix):
        gray_level, run_length, _ = rlmatrix.shape
        I, J = np.ogrid[0:gray_level, 0:run_length]
        return I, J+1

def calcuteS(rlmatrix):
        return np.apply_over_axes(np.sum, rlmatrix, axes=(0, 1))[0, 0]
    
    #The following code realizes the extraction of 11 gray runoff matrix features
   
    #1.SRE
def getShortRunEmphasis(rlmatrix):
            I, J = calcuteIJ(rlmatrix)
            numerator = np.apply_over_axes(np.sum, apply_over_degree(np.divide, rlmatrix, (J*J)), axes=(0, 1))[0, 0]
            S = calcuteS(rlmatrix)
            return numerator / S
    #2.LRE
def getLongRunEmphasis(rlmatrix):
        I, J = calcuteIJ(rlmatrix)
        numerator = np.apply_over_axes(np.sum, apply_over_degree(np.multiply, rlmatrix, (J*J)), axes=(0, 1))[0, 0]
        S = calcuteS(rlmatrix)
        return numerator / S
    #3.GLN
def getGrayLevelNonUniformity(rlmatrix):
        G = np.apply_over_axes(np.sum, rlmatrix, axes=1)
        numerator = np.apply_over_axes(np.sum, (G*G), axes=(0, 1))[0, 0]
        S = calcuteS(rlmatrix)
        return numerator / S
    # 4. RLN
def getRunLengthNonUniformity(rlmatrix):
            R = np.apply_over_axes(np.sum, rlmatrix, axes=0)
            numerator = np.apply_over_axes(np.sum, (R*R), axes=(0, 1))[0, 0]
            S = calcuteS(rlmatrix)
            return numerator / S

        # 5. RP
def getRunPercentage(rlmatrix):
            gray_level, run_length,_ = rlmatrix.shape
            num_voxels = gray_level * run_length
            return calcuteS(rlmatrix) / num_voxels

        # 6. LGLRE
def getLowGrayLevelRunEmphasis(rlmatrix):
            I, J = calcuteIJ(rlmatrix)
            numerator = np.apply_over_axes(np.sum, apply_over_degree(np.divide, rlmatrix, (I*I)), axes=(0, 1))[0, 0]
            S = calcuteS(rlmatrix)
            return numerator / S

        # 7. HGL   
def getHighGrayLevelRunEmphais(rlmatrix):
        I, J = calcuteIJ(rlmatrix)
        numerator = np.apply_over_axes(np.sum, apply_over_degree(np.multiply, rlmatrix, (I*I)), axes=(0, 1))[0, 0]
        S = calcuteS(rlmatrix)
        return numerator / S

        # 8. SRLGLE
def getShortRunLowGrayLevelEmphasis(rlmatrix):
        I, J = calcuteIJ(rlmatrix)
        numerator = np.apply_over_axes(np.sum, apply_over_degree(np.divide, rlmatrix, (I*I*J*J)), axes=(0, 1))[0, 0]
        S = calcuteS(rlmatrix)
        return numerator / S
    # 9. SRHGLE
def getShortRunHighGrayLevelEmphasis(rlmatrix):
        I, J = calcuteIJ(rlmatrix)
        temp = apply_over_degree(np.multiply, rlmatrix, (I*I))
        print('-----------------------')
        numerator = np.apply_over_axes(np.sum, apply_over_degree(np.divide, temp, (J*J)), axes=(0, 1))[0, 0]
        S = calcuteS(rlmatrix)
        return numerator / S
 
    # 10. LRLGLE
def getLongRunLow(rlmatrix):
        I, J = calcuteIJ(rlmatrix)
        temp = apply_over_degree(np.multiply, rlmatrix, (J*J))
        numerator = np.apply_over_axes(np.sum, apply_over_degree(np.divide, temp, (J*J)), axes=(0, 1))[0, 0]
        S = calcuteS(rlmatrix)
        return numerator / S
 
    # 11. LRHGLE
def getLongRunHighGrayLevelEmphais(rlmatrix):
        I, J = calcuteIJ(rlmatrix)
        numerator = np.apply_over_axes(np.sum,apply_over_degree(np.multiply, rlmatrix, (I*I*J*J)), axes=(0, 1))[0, 0]
        S = calcuteS(rlmatrix)
        return numerator / S

#import getGrayRumatrix
from PIL import Image
import numpy as np
from itertools import groupby
import csv
import warnings
warnings.filterwarnings("ignore")
import cv2
import os
import glob
import time

tic=time.time()

img_dir="/content/drive/MyDrive/Colab Notebooks/Zahid sir Work/Feature Extract/NORM" #Enter the directory where all the images are stored
data_path=os.path.join(img_dir,'*g')
files=glob.glob(data_path)
i=0
for path in files:
        data = 0
        img = Image.open(path) 
        img = img.convert('L')
        data=np.array(img)

        DEG = [['deg0'], ['deg45'], ['deg90'], ['deg135']]

        with open('/content/drive/MyDrive/Colab Notebooks/Zahid sir Work/Feature Extract/Glrlm feature extract/GLRL_norm.csv','a+',newline='',encoding='utf-8') as f:
                csv_writer = csv.writer(f)
                
                if i==0:
                        csv_writer.writerow(['deg0_SRE','deg45_SRE','deg90_SRE','deg135_SRE','deg0_LRE','deg45_LRE','deg90_LRE','deg135_LRE',
                                             'deg0_GLN','deg45_GLN','deg90_GLN','deg135_GLN','deg0_RLN','deg45_RLN','deg90_RLN','deg135_RLN',
                                             'deg0_RP','deg45_RP','deg90_RP','deg135_RP','deg0_LGLRE','deg45_LGLRE','deg90_LGLRE','deg135_LGLRE',
                                             'deg0_HGL','deg45_HGL','deg90_HGL','deg135_HGL','deg0_SRLGLE','deg45_SRLGLE','deg90_SRLGLE','deg135_SRLGLE',
                                             'deg0_SRHGLE','deg45_SRHGLE','deg90_SRHGLE','deg135_SRHGLE','deg0_LRLGLE','deg45_LRLGLE','deg90_LRLGLE','deg135_LRLGLE',
                                             'deg0_LRHGLE','deg45_LRHGLE','deg90_LRHGLE','deg135_LRHGLE'])
                
                print("Processing Image",i+1)
                i+=1
                SRE_l=[]
                LRE_l=[]
                GLN_l=[]
                RLN_l=[]
                RP_l=[]
                LGLRE_l=[]
                HGL_l=[]
                SRLGLE_l=[]
                SRHGLE_l=[]
                LRLGLE_l=[]
                LRHGLE_l=[]
                for deg in DEG:
                    now_deg = deg[0]
                    test_data = getGrayLevelRumatrix(data,deg)
                    

                    #1
                    SRE = getShortRunEmphasis(test_data) 
                    SRE = np.squeeze(SRE)
                    SRE_l.append(SRE)
                 

                    #2
                    LRE = getLongRunEmphasis(test_data)
                    LRE = np.squeeze(LRE)
                    LRE_l.append(LRE)
                    
                    #3
                    GLN = getGrayLevelNonUniformity(test_data)
                    GLN = np.squeeze(GLN)
                    GLN_l.append(GLN)
                    
                    #4
                    RLN = getRunLengthNonUniformity(test_data)
                    RLN = np.squeeze(RLN)
                    RLN_l.append(RLN)
                    
                    #5
                    RP = getRunPercentage(test_data)
                    RP = np.squeeze(RP)
                    RP_l.append(RP)
                    
                    #6
                    LGLRE = getLowGrayLevelRunEmphasis(test_data)
                    LGLRE = np.squeeze(LGLRE)
                    LGLRE_l.append(LGLRE)
                    
                    #7
                    HGL = getHighGrayLevelRunEmphais(test_data)
                    HGL = np.squeeze(HGL)
                    HGL_l.append(HGL)
                    
                    #8
                    SRLGLE = getShortRunLowGrayLevelEmphasis(test_data)
                    SRLGLE = np.squeeze(SRLGLE)
                    SRLGLE_l.append(SRLGLE)
                    
                    #9
                    SRHGLE = getShortRunHighGrayLevelEmphasis(test_data)
                    SRHGLE = np.squeeze(SRHGLE)
                    SRHGLE_l.append(SRHGLE)
                    
                    #10
                    LRLGLE = getLongRunLow(test_data)
                    LRLGLE = np.squeeze(LRLGLE)
                    LRLGLE_l.append(LRLGLE)
                    
                    #11
                    LRHGLE = getLongRunHighGrayLevelEmphais(test_data)
                    LRHGLE = np.squeeze(LRHGLE)
                    LRHGLE_l.append(LRHGLE)
            

                csv_writer.writerow(SRE_l+LRE_l+GLN_l+RLN_l+RP_l+LGLRE_l+HGL_l+SRLGLE_l+SRHGLE_l+LRLGLE_l+LRHGLE_l)

toc=time.time()
print("Computation time is: {} minutes.".format(str((toc-tic)/60)))
# Out:
# Streaming output truncated to the last 5000 lines.
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7765
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7766
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7767
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7768
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7769
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7770
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7771
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7772
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7773
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7774
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7775
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7776
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7777
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7778
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7779
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7780
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7781
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7782
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7783
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7784
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7785
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7786
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7787
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7788
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7789
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7790
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7791
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7792
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7793
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7794
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7795
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7796
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7797
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7798
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7799
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7800
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7801
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7802
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7803
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7804
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7805
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7806
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7807
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7808
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7809
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7810
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7811
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7812
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7813
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7814
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7815
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7816
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7817
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7818
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7819
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7820
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7821
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7822
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7823
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7824
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7825
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7826
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7827
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7828
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7829
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7830
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7831
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7832
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7833
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7834
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7835
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7836
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7837
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7838
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7839
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7840
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7841
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7842
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7843
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7844
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7845
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7846
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7847
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7848
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7849
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7850
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7851
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7852
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7853
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7854
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7855
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7856
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7857
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7858
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7859
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7860
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7861
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7862
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7863
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7864
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7865
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7866
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7867
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7868
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7869
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7870
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7871
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7872
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7873
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7874
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7875
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7876
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7877
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7878
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7879
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7880
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7881
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7882
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7883
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7884
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7885
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7886
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7887
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7888
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7889
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7890
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7891
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7892
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7893
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7894
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7895
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7896
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7897
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7898
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7899
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7900
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7901
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7902
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7903
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7904
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7905
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7906
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7907
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7908
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7909
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7910
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7911
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7912
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7913
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7914
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7915
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7916
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7917
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7918
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7919
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7920
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7921
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7922
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7923
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7924
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7925
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7926
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7927
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7928
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7929
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7930
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7931
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7932
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7933
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7934
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7935
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7936
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7937
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7938
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7939
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7940
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7941
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7942
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7943
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7944
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7945
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7946
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7947
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7948
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7949
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7950
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7951
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7952
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7953
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7954
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7955
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7956
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7957
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7958
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7959
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7960
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7961
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7962
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7963
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7964
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7965
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7966
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7967
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7968
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7969
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7970
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7971
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7972
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7973
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7974
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7975
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7976
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7977
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7978
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7979
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7980
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7981
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7982
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7983
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7984
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7985
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7986
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7987
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7988
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7989
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7990
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7991
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7992
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7993
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7994
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7995
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7996
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7997
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7998
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 7999
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8000
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8001
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8002
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8003
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8004
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8005
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8006
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8007
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8008
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8009
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8010
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8011
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8012
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8013
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8014
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8015
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8016
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8017
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8018
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8019
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8020
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8021
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8022
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8023
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8024
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8025
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8026
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8027
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8028
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8029
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8030
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8031
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8032
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8033
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8034
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8035
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8036
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8037
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8038
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8039
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8040
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8041
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8042
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8043
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8044
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8045
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8046
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8047
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8048
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8049
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8050
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8051
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8052
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8053
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8054
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8055
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8056
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8057
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8058
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8059
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8060
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8061
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8062
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8063
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8064
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8065
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8066
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8067
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8068
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8069
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8070
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8071
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8072
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8073
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8074
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8075
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8076
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8077
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8078
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8079
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8080
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8081
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8082
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8083
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8084
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8085
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8086
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8087
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8088
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8089
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8090
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8091
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8092
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8093
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8094
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8095
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8096
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8097
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8098
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8099
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8100
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8101
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8102
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8103
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8104
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8105
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8106
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8107
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8108
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8109
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8110
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8111
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8112
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8113
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8114
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8115
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8116
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8117
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8118
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8119
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8120
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8121
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8122
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8123
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8124
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8125
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8126
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8127
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8128
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8129
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8130
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8131
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8132
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8133
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8134
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8135
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8136
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8137
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8138
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8139
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8140
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8141
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8142
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8143
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8144
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8145
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8146
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8147
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8148
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8149
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8150
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8151
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8152
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8153
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8154
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8155
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8156
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8157
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8158
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8159
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8160
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8161
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8162
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8163
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8164
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8165
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8166
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8167
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8168
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8169
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8170
# -----------------------
# ...
# Processing Image 8629
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8630
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8631
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8632
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8633
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8634
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8635
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8636
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8637
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8638
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8639
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8640
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8641
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8642
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8643
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8644
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8645
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8646
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8647
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8648
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8649
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8650
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8651
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8652
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8653
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8654
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8655
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8656
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8657
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8658
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8659
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8660
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8661
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8662
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8663
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8664
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8665
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8666
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8667
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8668
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8669
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8670
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8671
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8672
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8673
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8674
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8675
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8676
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8677
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8678
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8679
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8680
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8681
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8682
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8683
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8684
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8685
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8686
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8687
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8688
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8689
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8690
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8691
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8692
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8693
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8694
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8695
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8696
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8697
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8698
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8699
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8700
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8701
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8702
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8703
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8704
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8705
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8706
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8707
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8708
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8709
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8710
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8711
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8712
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8713
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8714
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8715
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8716
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8717
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8718
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8719
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8720
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8721
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8722
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8723
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8724
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8725
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8726
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8727
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8728
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8729
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8730
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8731
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8732
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8733
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8734
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8735
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8736
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8737
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8738
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8739
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8740
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8741
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8742
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8743
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8744
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8745
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8746
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8747
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8748
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8749
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8750
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8751
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8752
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8753
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8754
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8755
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8756
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8757
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8758
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8759
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8760
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8761
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8762
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Processing Image 8763
# -----------------------
# -----------------------
# -----------------------
# -----------------------
# Computation time is: 95.77317812840144 minutes.
