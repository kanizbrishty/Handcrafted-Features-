# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd 
import numpy as np
# %matplotlib inline
import PIL
import tqdm
import pickle
import numpy as np
import matplotlib.pyplot as plt
from torchvision import datasets
from skimage.filters import gabor
from skimage.feature import local_binary_pattern, greycomatrix, greycoprops
import numpy as np
import pandas as pd
import cv2
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import os
import shutil

import warnings 
warnings.filterwarnings('ignore')
from sklearn.linear_model import LogisticRegression
import random
import pickle
from sklearn import model_selection
from pylab import *
#from kneed import KneeLocator
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import StandardScaler
import scipy.fftpack
from skimage import data, io
from scipy.signal import convolve2d as conv2
#import lightgbm as lgb
from sklearn import metrics
from sklearn.model_selection import train_test_split,cross_val_score
from skimage import color, data, restoration
from skimage.feature import greycomatrix,greycoprops

from sklearn.metrics import  accuracy_score, f1_score, precision_score,confusion_matrix, recall_score, roc_auc_score
from xgboost import XGBClassifier
from sklearn.ensemble import RandomForestClassifier,AdaBoostClassifier
from sklearn.svm import SVC

from sklearn import preprocessing

import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

from skimage import data
from skimage.filters import threshold_otsu
from skimage.segmentation import clear_border
from skimage.measure import label, regionprops
from skimage.morphology import closing, square
from skimage.color import label2rgb
import skimage.io as io
import skimage as sk
from skimage import measure
import math
from math import sqrt
from skimage import io, color, img_as_ubyte
from skimage.feature import greycomatrix, greycoprops
from sklearn.metrics.cluster import entropy
from scipy.stats import skew, kurtosis
from numpy import asarray
from PIL import Image
from math import sqrt

import skimage as sk
from skimage import measure

from numpy import asarray
from PIL import Image
import math
from math import sqrt

import skimage as sk
from skimage import measure

from numpy import asarray
from PIL import Image
from skimage import io, color, img_as_ubyte
from skimage.feature import greycomatrix, greycoprops
from sklearn.metrics.cluster import entropy

import scipy
import cv2
from scipy.stats import skew, kurtosis
import skimage
from skimage.filters import threshold_otsu

# %% [markdown]
# ## **FOr Grade -01**

# %%
####################### feature extraction###################




#############give directory 

dirr1= r'/content/drive/MyDrive/Breast Cancer/Final Work/Dataset/Grade_1' #### source folder

csv=r'/content/drive/MyDrive/Breast Cancer/Final Work/CSV File/LBP_Grade_1.csv' ### csv save path
### must change csv path

c=1 ### c=class 1=0 or class 2=1  

#####################################################################################################



black=0
j=0
df1 = pd.DataFrame(columns=['class', 'Area', 'PA_ratio', 'Solidity', 'Circularity', 'EquivDiameter', 'ConvexArea', 'Extent', 'FilledArea', 'Major axis length', 'Minor axis length', 'Mean', 'Standard Deviation', 'Shannon_Entropy', 'Glcm_entropy', 'Skewness', 'kurtosis','lbp_energy','lbp_entropy','gabor_energy','gabor_entropy'])

onlyfiles = next(os.walk(dirr1))[2] #dir is your directory path as string
print(len(onlyfiles))



for i in os.listdir(dirr1):
    path = os.path.join(dirr1,i)
    im = io.imread(path)
    height = im.shape[0]
    width = im.shape[1]
    print('working on img ',i)
    props=sk.measure.regionprops(im)
    
    
    if len(props)!=0:
        pr=[]
        for prop in props: 
            pr.append(prop.area)
        num = np.array(pr)
        a=props[np.argmax(num)]
        
        imgcv = cv2.imread(path)
        gray = cv2.cvtColor(imgcv,cv2.COLOR_BGR2GRAY)
        ret, thresh = cv2.threshold(gray,0,255,cv2.THRESH_BINARY)
        cv2.waitKey(0)
        cv2.destroyAllWindows()
        ave = cv2.mean(thresh)[0]/255
        area = ave*height*width###########################
        try:
            image=skimage.io.imread(path,as_gray=True)
            thresh = threshold_otsu(image)
            binary = image > thresh
            perimeter=measure.perimeter(binary)################


            PA_ratio=round(perimeter/area,4)
            EquivDiameter=round(sqrt(4*area/math.pi),4)
            Circularity=round((4*area*math.pi)/(perimeter*perimeter),4)
            ConvexArea=round(a.convex_area,4)

        except:
            
            print('black found \n')
            black+=1
      
            continue    
       









        Extent=round(a.extent,4)
        Solidity=round(area/ConvexArea,4)
        FilledArea=round(a.filled_area,4)
        maj_ax_le=round(a.major_axis_length,4)
        min_ax_le=round(a.minor_axis_length,4)
        #LS_ratio=round(maj_ax_le/min_ax_le,4)
        EulerNumber=round(a.euler_number,4)



        image=Image.open(path)
        pixels=asarray(image)
        # convert from integers to floats
        pixels=pixels.astype('float32')
        # calculate global mean
        mean=round(pixels.mean(),3)

        pixels=asarray(image)
        # convert from integers to floats
        pixels=pixels.astype('float32')
        # calculate global mean and standard deviation
        std=round(pixels.std(),3)

        #print('Standard Deviation: %.3f' % (std))
        sha_entropy=round(skimage.measure.shannon_entropy(image),4)


        #LBP & Gabor
        img_gray = image.convert('L') 
        img_arr = np.array(img_gray)
        feat_lbp = local_binary_pattern(img_arr,8,1,'uniform') #Radius = 1, No. of neighbours = 8
        feat_lbp = np.uint8((feat_lbp/feat_lbp.max())*255)
        lbp_hist,_ = np.histogram(feat_lbp,8)
        lbp_hist = np.array(lbp_hist,dtype=float)
        lbp_prob = np.divide(lbp_hist,np.sum(lbp_hist))
        lbp_energy = np.sum(lbp_prob**2)
        lbp_entropy = -np.sum(np.multiply(lbp_prob,np.log2(lbp_prob)))

        gaborFilt_real,gaborFilt_imag = gabor(img_arr,frequency=0.6)
        gaborFilt = (gaborFilt_real**2+gaborFilt_imag**2)//2
        gabor_hist,_ = np.histogram(gaborFilt,8)
        gabor_hist = np.array(gabor_hist,dtype=float)
        gabor_prob = np.divide(gabor_hist,np.sum(gabor_hist))
        gabor_energy = np.sum(gabor_prob**2)
        gabor_entropy = -np.sum(np.multiply(gabor_prob,np.log2(gabor_prob)))

        


        rgbImg=io.imread(path)
        grayImg=img_as_ubyte(color.rgb2gray(rgbImg))
        distances=[1,2,3]
        angles=[0,np.pi/4,np.pi/2,3*np.pi/4]
        properties=['energy','homogeneity']
        glcm=greycomatrix(grayImg,distances=distances,angles=angles,symmetric=True,normed=True)
        glcm_entropy=round(-np.sum(glcm*np.log2(glcm+(glcm==0))),4)
        im=cv2.imread(path)
        colon_number=0
        Skewness=round(skew(im.reshape(-1,3)[:,colon_number]),4)
        Kurtosis=round(kurtosis(im.reshape(-1,3)[:,colon_number]),4)
        #df1.loc[j] =list(area)+list(PA_ratio)+list(Solidity)+list(Circularity)+list(EquivDiameter)+list(ConvexArea)+list(Extent)+list(FilledArea)+list(maj_ax_le)+list(min_ax_le)+list(mean)+list(std)+list(sha_entropy)+list(glcm_entropy)+list(Skewness)+list(Kurtosis)
        df1.loc[j]=({'class':c,'Area':area,
                          'PA_ratio':PA_ratio,
                          'Solidity':Solidity,
                          'Circularity':Circularity,
                          'EquivDiameter':EquivDiameter,
                          'ConvexArea':ConvexArea,
                          'Extent':Extent,
                          'FilledArea':FilledArea,
                          'Major axis length':maj_ax_le,
                          'Minor axis length':min_ax_le,
                          #'LS_ Ratio':[LS_ratio],
                          'Mean':mean,
                          'Standard Deviation':std,
                          'Shannon_Entropy':sha_entropy,
                          'Glcm_entropy':glcm_entropy,
                          'Skewness':Skewness,
                          'kurtosis':Kurtosis,
                          'lbp_energy':lbp_energy,
                          'lbp_entropy':lbp_entropy,
                          'gabor_energy':gabor_energy,
                          'gabor_entropy':gabor_entropy})

        j+=1
    else:
        print('black found \n')
        black+=1
    print('\n')
      
print('\n\n\n') 
print('black images found: ',black, 'out of total image : ',len(onlyfiles), )    
print('\n\n\n\n\n\n')    
    
    
    
    
frames = df1


############################################### give directy to save csv file

#roidata_set = pd.concat(frames)
frames.to_csv(csv,index=False)### give train.csv path
#print(frames)

###############################################################################


######## after completing train set give me an ss of the output that will be printed below... do the same for val and test also.
# Out:
# 317
# working on img  gamma_corr 0.png
#
#
# working on img  gamma_corr 1.png
#
#
# working on img  gamma_corr 2.png
#
#
# working on img  gamma_corr 3.png
#
#
# working on img  gamma_corr 4.png
#
#
# working on img  gamma_corr 5.png
#
#
# working on img  gamma_corr 6.png
#
#
# working on img  gamma_corr 7.png
#
#
# working on img  gamma_corr 8.png
#
#
# working on img  gamma_corr 9.png
#
#
# working on img  gamma_corr 10.png
#
#
# working on img  gamma_corr 11.png
#
#
# working on img  gamma_corr 12.png
#
#
# working on img  gamma_corr 13.png
#
#
# working on img  gamma_corr 14.png
#
#
# working on img  gamma_corr 15.png
#
#
# working on img  gamma_corr 16.png
#
#
# working on img  gamma_corr 17.png
#
#
# working on img  gamma_corr 18.png
#
#
# working on img  gamma_corr 19.png
#
#
# working on img  gamma_corr 20.png
#
#
# working on img  gamma_corr 21.png
#
#
# working on img  gamma_corr 22.png
#
#
# working on img  gamma_corr 23.png
#
#
# working on img  gamma_corr 24.png
#
#
# working on img  gamma_corr 25.png
#
#
# working on img  gamma_corr 26.png
#
#
# working on img  gamma_corr 27.png
#
#
# working on img  gamma_corr 28.png
#
#
# working on img  gamma_corr 29.png
#
#
# working on img  gamma_corr 30.png
#
#
# working on img  gamma_corr 31.png
#
#
# working on img  gamma_corr 32.png
#
#
# working on img  gamma_corr 33.png
#
#
# working on img  gamma_corr 34.png
#
#
# working on img  gamma_corr 35.png
#
#
# working on img  gamma_corr 36.png
#
#
# working on img  gamma_corr 37.png
#
#
# working on img  gamma_corr 38.png
#
#
# working on img  gamma_corr 39.png
#
#
# working on img  gamma_corr 40.png
#
#
# working on img  gamma_corr 41.png
#
#
# working on img  gamma_corr 42.png
#
#
# working on img  gamma_corr 43.png
#
#
# working on img  gamma_corr 44.png
#
#
# working on img  gamma_corr 45.png
#
#
# working on img  gamma_corr 46.png
#
#
# working on img  gamma_corr 47.png
#
#
# working on img  gamma_corr 48.png
#
#
# working on img  gamma_corr 49.png
#
#
# working on img  gamma_corr 50.png
#
#
# working on img  gamma_corr 51.png
#
#
# working on img  gamma_corr 52.png
#
#
# working on img  gamma_corr 53.png
#
#
# working on img  gamma_corr 54.png
#
#
# working on img  gamma_corr 55.png
#
#
# working on img  gamma_corr 56.png
#
#
# working on img  gamma_corr 57.png
#
#
# working on img  gamma_corr 58.png
#
#
# working on img  gamma_corr 59.png
#
#
# working on img  gamma_corr 60.png
#
#
# working on img  gamma_corr 61.png
#
#
# working on img  gamma_corr 62.png
#
#
# working on img  gamma_corr 63.png
#
#
# working on img  gamma_corr 64.png
#
#
# working on img  gamma_corr 65.png
#
#
# working on img  gamma_corr 66.png
#
#
# working on img  gamma_corr 67.png
#
#
# working on img  gamma_corr 68.png
#
#
# working on img  gamma_corr 69.png
#
#
# working on img  gamma_corr 70.png
#
#
# working on img  gamma_corr 71.png
#
#
# working on img  gamma_corr 72.png
#
#
# working on img  gamma_corr 73.png
#
#
# working on img  gamma_corr 74.png
#
#
# working on img  gamma_corr 75.png
#
#
# working on img  gamma_corr 76.png
#
#
# working on img  gamma_corr 77.png
#
#
# working on img  gamma_corr 78.png
#
#
# working on img  gamma_corr 79.png
#
#
# working on img  gamma_corr 80.png
#
#
# working on img  gamma_corr 81.png
#
#
# working on img  gamma_corr 82.png
#
#
# working on img  gamma_corr 83.png
#
#
# working on img  gamma_corr 84.png
#
#
# working on img  gamma_corr 85.png
#
#
# working on img  gamma_corr 86.png
#
#
# working on img  gamma_corr 87.png
#
#
# working on img  gamma_corr 88.png
#
#
# working on img  gamma_corr 89.png
#
#
# working on img  gamma_corr 90.png
#
#
# working on img  gamma_corr 91.png
#
#
# working on img  gamma_corr 92.png
#
#
# working on img  gamma_corr 93.png
#
#
# working on img  gamma_corr 94.png
#
#
# working on img  gamma_corr 95.png
#
#
# working on img  gamma_corr 96.png
#
#
# working on img  gamma_corr 97.png
#
#
# working on img  gamma_corr 98.png
#
#
# working on img  gamma_corr 99.png
#
#
# working on img  gamma_corr 100.png
#
#
# working on img  gamma_corr 101.png
#
#
# working on img  gamma_corr 102.png
#
#
# working on img  gamma_corr 103.png
#
#
# working on img  gamma_corr 104.png
#
#
# working on img  gamma_corr 105.png
#
#
# working on img  gamma_corr 106.png
#
#
# working on img  gamma_corr 107.png
#
#
# working on img  gamma_corr 108.png
#
#
# working on img  gamma_corr 109.png
#
#
# working on img  gamma_corr 110.png
#
#
# working on img  gamma_corr 111.png
#
#
# working on img  gamma_corr 112.png
#
#
# working on img  gamma_corr 113.png
#
#
# working on img  gamma_corr 114.png
#
#
# working on img  gamma_corr 115.png
#
#
# working on img  gamma_corr 116.png
#
#
# working on img  gamma_corr 117.png
#
#
# working on img  gamma_corr 118.png
#
#
# working on img  gamma_corr 119.png
#
#
# working on img  gamma_corr 120.png
#
#
# working on img  gamma_corr 121.png
#
#
# working on img  gamma_corr 122.png
#
#
# working on img  gamma_corr 123.png
#
#
# working on img  gamma_corr 124.png
#
#
# working on img  gamma_corr 125.png
#
#
# working on img  gamma_corr 126.png
#
#
# working on img  gamma_corr 127.png
#
#
# working on img  gamma_corr 128.png
#
#
# working on img  gamma_corr 129.png
#
#
# working on img  gamma_corr 130.png
#
#
# working on img  gamma_corr 131.png
#
#
# working on img  gamma_corr 132.png
#
#
# working on img  gamma_corr 133.png
#
#
# working on img  gamma_corr 134.png
#
#
# working on img  gamma_corr 135.png
#
#
# working on img  gamma_corr 136.png
#
#
# working on img  gamma_corr 137.png
#
#
# working on img  gamma_corr 138.png
#
#
# working on img  gamma_corr 139.png
#
#
# working on img  gamma_corr 140.png
#
#
# working on img  gamma_corr 141.png
#
#
# working on img  gamma_corr 142.png
#
#
# working on img  gamma_corr 143.png
#
#
# working on img  gamma_corr 144.png
#
#
# working on img  gamma_corr 145.png
#
#
# working on img  gamma_corr 146.png
#
#
# working on img  gamma_corr 147.png
#
#
# working on img  gamma_corr 148.png
#
#
# working on img  gamma_corr 149.png
#
#
# working on img  gamma_corr 150.png
#
#
# working on img  gamma_corr 151.png
#
#
# working on img  gamma_corr 152.png
#
#
# working on img  gamma_corr 153.png
#
#
# working on img  gamma_corr 154.png
#
#
# working on img  gamma_corr 155.png
#
#
# working on img  gamma_corr 156.png
#
#
# working on img  gamma_corr 157.png
#
#
# working on img  gamma_corr 158.png
#
#
# working on img  gamma_corr 159.png
#
#
# working on img  gamma_corr 160.png
#
#
# working on img  gamma_corr 161.png
#
#
# working on img  gamma_corr 162.png
#
#
# working on img  gamma_corr 163.png
#
#
# working on img  gamma_corr 164.png
#
#
# working on img  gamma_corr 165.png
#
#
# working on img  gamma_corr 166.png
#
#
# working on img  gamma_corr 167.png
#
#
# working on img  gamma_corr 168.png
#
#
# working on img  gamma_corr 169.png
#
#
# working on img  gamma_corr 170.png
#
#
# working on img  gamma_corr 171.png
#
#
# working on img  gamma_corr 172.png
#
#
# working on img  gamma_corr 173.png
#
#
# working on img  gamma_corr 174.png
#
#
# working on img  gamma_corr 175.png
#
#
# working on img  gamma_corr 176.png
#
#
# working on img  gamma_corr 177.png
#
#
# working on img  gamma_corr 178.png
#
#
# working on img  gamma_corr 179.png
#
#
# working on img  gamma_corr 180.png
#
#
# working on img  gamma_corr 181.png
#
#
# working on img  gamma_corr 182.png
#
#
# working on img  gamma_corr 183.png
#
#
# working on img  gamma_corr 184.png
#
#
# working on img  gamma_corr 185.png
#
#
# working on img  gamma_corr 186.png
#
#
# working on img  gamma_corr 187.png
#
#
# working on img  gamma_corr 188.png
#
#
# working on img  gamma_corr 189.png
#
#
# working on img  gamma_corr 190.png
#
#
# working on img  gamma_corr 191.png
#
#
# working on img  gamma_corr 192.png
#
#
# working on img  gamma_corr 193.png
#
#
# working on img  gamma_corr 194.png
#
#
# working on img  gamma_corr 195.png
#
#
# working on img  gamma_corr 196.png
#
#
# working on img  gamma_corr 197.png
#
#
# working on img  gamma_corr 198.png
#
#
# working on img  gamma_corr 199.png
#
#
# working on img  gamma_corr 200.png
#
#
# working on img  gamma_corr 201.png
#
#
# working on img  gamma_corr 202.png
#
#
# working on img  gamma_corr 203.png
#
#
# working on img  gamma_corr 204.png
#
#
# working on img  gamma_corr 205.png
#
#
# working on img  gamma_corr 206.png
#
#
# working on img  gamma_corr 207.png
#
#
# working on img  gamma_corr 208.png
#
#
# working on img  gamma_corr 209.png
#
#
# working on img  gamma_corr 210.png
#
#
# working on img  gamma_corr 211.png
#
#
# working on img  gamma_corr 212.png
#
#
# working on img  gamma_corr 213.png
#
#
# working on img  gamma_corr 214.png
#
#
# working on img  gamma_corr 215.png
#
#
# working on img  gamma_corr 216.png
#
#
# working on img  gamma_corr 217.png
#
#
# working on img  gamma_corr 218.png
#
#
# working on img  gamma_corr 219.png
#
#
# working on img  gamma_corr 220.png
#
#
# working on img  gamma_corr 221.png
#
#
# working on img  gamma_corr 222.png
#
#
# working on img  gamma_corr 223.png
#
#
# working on img  gamma_corr 224.png
#
#
# working on img  gamma_corr 225.png
#
#
# working on img  gamma_corr 226.png
#
#
# working on img  gamma_corr 227.png
#
#
# working on img  gamma_corr 228.png
#
#
# working on img  gamma_corr 229.png
#
#
# working on img  gamma_corr 230.png
#
#
# working on img  gamma_corr 231.png
#
#
# working on img  gamma_corr 232.png
#
#
# working on img  gamma_corr 233.png
#
#
# working on img  gamma_corr 234.png
#
#
# working on img  gamma_corr 235.png
#
#
# working on img  gamma_corr 236.png
#
#
# working on img  gamma_corr 237.png
#
#
# working on img  gamma_corr 238.png
#
#
# working on img  gamma_corr 239.png
#
#
# working on img  gamma_corr 240.png
#
#
# working on img  gamma_corr 241.png
#
#
# working on img  gamma_corr 242.png
#
#
# working on img  gamma_corr 243.png
#
#
# working on img  gamma_corr 244.png
#
#
# working on img  gamma_corr 245.png
#
#
# working on img  gamma_corr 246.png
#
#
# working on img  gamma_corr 247.png
#
#
# working on img  gamma_corr 248.png
#
#
# working on img  gamma_corr 249.png
#
#
# working on img  gamma_corr 250.png
#
#
# working on img  gamma_corr 251.png
#
#
# working on img  gamma_corr 252.png
#
#
# working on img  gamma_corr 253.png
#
#
# working on img  gamma_corr 254.png
#
#
# working on img  gamma_corr 255.png
#
#
# working on img  gamma_corr 256.png
#
#
# working on img  gamma_corr 257.png
#
#
# working on img  gamma_corr 258.png
#
#
# working on img  gamma_corr 259.png
#
#
# working on img  gamma_corr 260.png
#
#
# working on img  gamma_corr 261.png
#
#
# working on img  gamma_corr 262.png
#
#
# working on img  gamma_corr 263.png
#
#
# working on img  gamma_corr 264.png
#
#
# working on img  gamma_corr 265.png
#
#
# working on img  gamma_corr 266.png
#
#
# working on img  gamma_corr 267.png
#
#
# working on img  gamma_corr 268.png
#
#
# working on img  gamma_corr 269.png
#
#
# working on img  gamma_corr 270.png
#
#
# working on img  gamma_corr 271.png
#
#
# working on img  gamma_corr 272.png
#
#
# working on img  gamma_corr 273.png
#
#
# working on img  gamma_corr 274.png
#
#
# working on img  gamma_corr 275.png
#
#
# working on img  gamma_corr 276.png
#
#
# working on img  gamma_corr 277.png
#
#
# working on img  gamma_corr 278.png
#
#
# working on img  gamma_corr 279.png
#
#
# working on img  gamma_corr 280.png
#
#
# working on img  gamma_corr 281.png
#
#
# working on img  gamma_corr 282.png
#
#
# working on img  gamma_corr 283.png
#
#
# working on img  gamma_corr 284.png
#
#
# working on img  gamma_corr 285.png
#
#
# working on img  gamma_corr 286.png
#
#
# working on img  gamma_corr 287.png
#
#
# working on img  gamma_corr 288.png
#
#
# working on img  gamma_corr 289.png
#
#
# working on img  gamma_corr 290.png
#
#
# working on img  gamma_corr 291.png
#
#
# working on img  gamma_corr 292.png
#
#
# working on img  gamma_corr 293.png
#
#
# working on img  gamma_corr 294.png
#
#
# working on img  gamma_corr 295.png
#
#
# working on img  gamma_corr 296.png
#
#
# working on img  gamma_corr 297.png
#
#
# working on img  gamma_corr 298.png
#
#
# working on img  gamma_corr 299.png
#
#
# working on img  gamma_corr 300.png
#
#
# working on img  gamma_corr 301.png
#
#
# working on img  gamma_corr 302.png
#
#
# working on img  gamma_corr 303.png
#
#
# working on img  gamma_corr 304.png
#
#
# working on img  gamma_corr 305.png
#
#
# working on img  gamma_corr 306.png
#
#
# working on img  gamma_corr 307.png
#
#
# working on img  gamma_corr 308.png
#
#
# working on img  gamma_corr 309.png
#
#
# working on img  gamma_corr 310.png
#
#
# working on img  gamma_corr 311.png
#
#
# working on img  gamma_corr 312.png
#
#
# working on img  gamma_corr 313.png
#
#
# working on img  gamma_corr 314.png
#
#
# working on img  gamma_corr 315.png
#
#
# working on img  gamma_corr 316.png
#
#
#
#
#
#
# black images found:  0 out of total image :  317

# %%
####################### feature extraction###################




#############give directory 

dirr1= r'/content/drive/MyDrive/Breast Cancer/Final Work/Dataset/Grade_2' #### source folder

csv=r'/content/drive/MyDrive/Breast Cancer/Final Work/CSV File/LBP_Grade_2.csv' ### csv save path
### must change csv path

c=1 ### c=class 1=0 or class 2=1  

#####################################################################################################



black=0
j=0
df1 = pd.DataFrame(columns=['class', 'Area', 'PA_ratio', 'Solidity', 'Circularity', 'EquivDiameter', 'ConvexArea', 'Extent', 'FilledArea', 'Major axis length', 'Minor axis length', 'Mean', 'Standard Deviation', 'Shannon_Entropy', 'Glcm_entropy', 'Skewness', 'kurtosis','lbp_energy','lbp_entropy','gabor_energy','gabor_entropy'])

onlyfiles = next(os.walk(dirr1))[2] #dir is your directory path as string
print(len(onlyfiles))



for i in os.listdir(dirr1):
    path = os.path.join(dirr1,i)
    im = io.imread(path)
    height = im.shape[0]
    width = im.shape[1]
    print('working on img ',i)
    props=sk.measure.regionprops(im)
    
    
    if len(props)!=0:
        pr=[]
        for prop in props: 
            pr.append(prop.area)
        num = np.array(pr)
        a=props[np.argmax(num)]
        
        imgcv = cv2.imread(path)
        gray = cv2.cvtColor(imgcv,cv2.COLOR_BGR2GRAY)
        ret, thresh = cv2.threshold(gray,0,255,cv2.THRESH_BINARY)
        cv2.waitKey(0)
        cv2.destroyAllWindows()
        ave = cv2.mean(thresh)[0]/255
        area = ave*height*width###########################
        try:
            image=skimage.io.imread(path,as_gray=True)
            thresh = threshold_otsu(image)
            binary = image > thresh
            perimeter=measure.perimeter(binary)################


            PA_ratio=round(perimeter/area,4)
            EquivDiameter=round(sqrt(4*area/math.pi),4)
            Circularity=round((4*area*math.pi)/(perimeter*perimeter),4)
            ConvexArea=round(a.convex_area,4)

        except:
            
            print('black found \n')
            black+=1
      
            continue    
       









        Extent=round(a.extent,4)
        Solidity=round(area/ConvexArea,4)
        FilledArea=round(a.filled_area,4)
        maj_ax_le=round(a.major_axis_length,4)
        min_ax_le=round(a.minor_axis_length,4)
        #LS_ratio=round(maj_ax_le/min_ax_le,4)
        EulerNumber=round(a.euler_number,4)



        image=Image.open(path)
        pixels=asarray(image)
        # convert from integers to floats
        pixels=pixels.astype('float32')
        # calculate global mean
        mean=round(pixels.mean(),3)

        pixels=asarray(image)
        # convert from integers to floats
        pixels=pixels.astype('float32')
        # calculate global mean and standard deviation
        std=round(pixels.std(),3)

        #print('Standard Deviation: %.3f' % (std))
        sha_entropy=round(skimage.measure.shannon_entropy(image),4)


        #LBP & Gabor
        img_gray = image.convert('L') 
        img_arr = np.array(img_gray)
        feat_lbp = local_binary_pattern(img_arr,8,1,'uniform') #Radius = 1, No. of neighbours = 8
        feat_lbp = np.uint8((feat_lbp/feat_lbp.max())*255)
        lbp_hist,_ = np.histogram(feat_lbp,8)
        lbp_hist = np.array(lbp_hist,dtype=float)
        lbp_prob = np.divide(lbp_hist,np.sum(lbp_hist))
        lbp_energy = np.sum(lbp_prob**2)
        lbp_entropy = -np.sum(np.multiply(lbp_prob,np.log2(lbp_prob)))

        gaborFilt_real,gaborFilt_imag = gabor(img_arr,frequency=0.6)
        gaborFilt = (gaborFilt_real**2+gaborFilt_imag**2)//2
        gabor_hist,_ = np.histogram(gaborFilt,8)
        gabor_hist = np.array(gabor_hist,dtype=float)
        gabor_prob = np.divide(gabor_hist,np.sum(gabor_hist))
        gabor_energy = np.sum(gabor_prob**2)
        gabor_entropy = -np.sum(np.multiply(gabor_prob,np.log2(gabor_prob)))

        


        rgbImg=io.imread(path)
        grayImg=img_as_ubyte(color.rgb2gray(rgbImg))
        distances=[1,2,3]
        angles=[0,np.pi/4,np.pi/2,3*np.pi/4]
        properties=['energy','homogeneity']
        glcm=greycomatrix(grayImg,distances=distances,angles=angles,symmetric=True,normed=True)
        glcm_entropy=round(-np.sum(glcm*np.log2(glcm+(glcm==0))),4)
        im=cv2.imread(path)
        colon_number=0
        Skewness=round(skew(im.reshape(-1,3)[:,colon_number]),4)
        Kurtosis=round(kurtosis(im.reshape(-1,3)[:,colon_number]),4)
        #df1.loc[j] =list(area)+list(PA_ratio)+list(Solidity)+list(Circularity)+list(EquivDiameter)+list(ConvexArea)+list(Extent)+list(FilledArea)+list(maj_ax_le)+list(min_ax_le)+list(mean)+list(std)+list(sha_entropy)+list(glcm_entropy)+list(Skewness)+list(Kurtosis)
        df1.loc[j]=({'class':c,'Area':area,
                          'PA_ratio':PA_ratio,
                          'Solidity':Solidity,
                          'Circularity':Circularity,
                          'EquivDiameter':EquivDiameter,
                          'ConvexArea':ConvexArea,
                          'Extent':Extent,
                          'FilledArea':FilledArea,
                          'Major axis length':maj_ax_le,
                          'Minor axis length':min_ax_le,
                          #'LS_ Ratio':[LS_ratio],
                          'Mean':mean,
                          'Standard Deviation':std,
                          'Shannon_Entropy':sha_entropy,
                          'Glcm_entropy':glcm_entropy,
                          'Skewness':Skewness,
                          'kurtosis':Kurtosis,
                          'lbp_energy':lbp_energy,
                          'lbp_entropy':lbp_entropy,
                          'gabor_energy':gabor_energy,
                          'gabor_entropy':gabor_entropy})

        j+=1
    else:
        print('black found \n')
        black+=1
    print('\n')
      
print('\n\n\n') 
print('black images found: ',black, 'out of total image : ',len(onlyfiles), )    
print('\n\n\n\n\n\n')    
    
    
    
    
frames = df1


############################################### give directy to save csv file

#roidata_set = pd.concat(frames)
frames.to_csv(csv,index=False)### give train.csv path
#print(frames)

###############################################################################


######## after completing train set give me an ss of the output that will be printed below... do the same for val and test also.
# Out:
# 480
# working on img  gamma_corr 0.png
#
#
# working on img  gamma_corr 1.png
#
#
# working on img  gamma_corr 2.png
#
#
# working on img  gamma_corr 3.png
#
#
# working on img  gamma_corr 4.png
#
#
# working on img  gamma_corr 5.png
#
#
# working on img  gamma_corr 6.png
#
#
# working on img  gamma_corr 7.png
#
#
# working on img  gamma_corr 8.png
#
#
# working on img  gamma_corr 9.png
#
#
# working on img  gamma_corr 10.png
#
#
# working on img  gamma_corr 11.png
#
#
# working on img  gamma_corr 12.png
#
#
# working on img  gamma_corr 13.png
#
#
# working on img  gamma_corr 14.png
#
#
# working on img  gamma_corr 15.png
#
#
# working on img  gamma_corr 16.png
#
#
# working on img  gamma_corr 17.png
#
#
# working on img  gamma_corr 18.png
#
#
# working on img  gamma_corr 19.png
#
#
# working on img  gamma_corr 20.png
#
#
# working on img  gamma_corr 21.png
#
#
# working on img  gamma_corr 22.png
#
#
# working on img  gamma_corr 23.png
#
#
# working on img  gamma_corr 24.png
#
#
# working on img  gamma_corr 25.png
#
#
# working on img  gamma_corr 26.png
#
#
# working on img  gamma_corr 27.png
#
#
# working on img  gamma_corr 28.png
#
#
# working on img  gamma_corr 29.png
#
#
# working on img  gamma_corr 30.png
#
#
# working on img  gamma_corr 31.png
#
#
# working on img  gamma_corr 32.png
#
#
# working on img  gamma_corr 33.png
#
#
# working on img  gamma_corr 34.png
#
#
# working on img  gamma_corr 35.png
#
#
# working on img  gamma_corr 36.png
#
#
# working on img  gamma_corr 37.png
#
#
# working on img  gamma_corr 38.png
#
#
# working on img  gamma_corr 39.png
#
#
# working on img  gamma_corr 40.png
#
#
# working on img  gamma_corr 41.png
#
#
# working on img  gamma_corr 42.png
#
#
# working on img  gamma_corr 43.png
#
#
# working on img  gamma_corr 44.png
#
#
# working on img  gamma_corr 45.png
#
#
# working on img  gamma_corr 46.png
#
#
# working on img  gamma_corr 47.png
#
#
# working on img  gamma_corr 48.png
#
#
# working on img  gamma_corr 49.png
#
#
# working on img  gamma_corr 50.png
#
#
# working on img  gamma_corr 51.png
#
#
# working on img  gamma_corr 52.png
#
#
# working on img  gamma_corr 53.png
#
#
# working on img  gamma_corr 54.png
#
#
# working on img  gamma_corr 55.png
#
#
# working on img  gamma_corr 56.png
#
#
# working on img  gamma_corr 57.png
#
#
# working on img  gamma_corr 58.png
#
#
# working on img  gamma_corr 59.png
#
#
# working on img  gamma_corr 60.png
#
#
# working on img  gamma_corr 61.png
#
#
# working on img  gamma_corr 62.png
#
#
# working on img  gamma_corr 63.png
#
#
# working on img  gamma_corr 64.png
#
#
# working on img  gamma_corr 65.png
#
#
# working on img  gamma_corr 66.png
#
#
# working on img  gamma_corr 67.png
#
#
# working on img  gamma_corr 68.png
#
#
# working on img  gamma_corr 69.png
#
#
# working on img  gamma_corr 70.png
#
#
# working on img  gamma_corr 71.png
#
#
# working on img  gamma_corr 72.png
#
#
# working on img  gamma_corr 73.png
#
#
# working on img  gamma_corr 74.png
#
#
# working on img  gamma_corr 75.png
#
#
# working on img  gamma_corr 76.png
#
#
# working on img  gamma_corr 77.png
#
#
# working on img  gamma_corr 78.png
#
#
# working on img  gamma_corr 79.png
#
#
# working on img  gamma_corr 80.png
#
#
# working on img  gamma_corr 81.png
#
#
# working on img  gamma_corr 82.png
#
#
# working on img  gamma_corr 83.png
#
#
# working on img  gamma_corr 84.png
#
#
# working on img  gamma_corr 85.png
#
#
# working on img  gamma_corr 86.png
#
#
# working on img  gamma_corr 87.png
#
#
# working on img  gamma_corr 88.png
#
#
# working on img  gamma_corr 89.png
#
#
# working on img  gamma_corr 90.png
#
#
# working on img  gamma_corr 91.png
#
#
# working on img  gamma_corr 92.png
#
#
# working on img  gamma_corr 93.png
#
#
# working on img  gamma_corr 94.png
#
#
# working on img  gamma_corr 95.png
#
#
# working on img  gamma_corr 96.png
#
#
# working on img  gamma_corr 97.png
#
#
# working on img  gamma_corr 98.png
#
#
# working on img  gamma_corr 99.png
#
#
# working on img  gamma_corr 100.png
#
#
# working on img  gamma_corr 101.png
#
#
# working on img  gamma_corr 102.png
#
#
# working on img  gamma_corr 103.png
#
#
# working on img  gamma_corr 104.png
#
#
# working on img  gamma_corr 105.png
#
#
# working on img  gamma_corr 106.png
#
#
# working on img  gamma_corr 107.png
#
#
# working on img  gamma_corr 108.png
#
#
# working on img  gamma_corr 109.png
#
#
# working on img  gamma_corr 110.png
#
#
# working on img  gamma_corr 111.png
#
#
# working on img  gamma_corr 112.png
#
#
# working on img  gamma_corr 113.png
#
#
# working on img  gamma_corr 114.png
#
#
# working on img  gamma_corr 115.png
#
#
# working on img  gamma_corr 116.png
#
#
# working on img  gamma_corr 117.png
#
#
# working on img  gamma_corr 118.png
#
#
# working on img  gamma_corr 119.png
#
#
# working on img  gamma_corr 120.png
#
#
# working on img  gamma_corr 121.png
#
#
# working on img  gamma_corr 122.png
#
#
# working on img  gamma_corr 123.png
#
#
# working on img  gamma_corr 124.png
#
#
# working on img  gamma_corr 125.png
#
#
# working on img  gamma_corr 126.png
#
#
# working on img  gamma_corr 127.png
#
#
# working on img  gamma_corr 128.png
#
#
# working on img  gamma_corr 129.png
#
#
# working on img  gamma_corr 130.png
#
#
# working on img  gamma_corr 131.png
#
#
# working on img  gamma_corr 132.png
#
#
# working on img  gamma_corr 133.png
#
#
# working on img  gamma_corr 134.png
#
#
# working on img  gamma_corr 135.png
#
#
# working on img  gamma_corr 136.png
#
#
# working on img  gamma_corr 137.png
#
#
# working on img  gamma_corr 138.png
#
#
# working on img  gamma_corr 139.png
#
#
# working on img  gamma_corr 140.png
#
#
# working on img  gamma_corr 141.png
#
#
# working on img  gamma_corr 142.png
#
#
# working on img  gamma_corr 143.png
#
#
# working on img  gamma_corr 144.png
#
#
# working on img  gamma_corr 145.png
#
#
# working on img  gamma_corr 146.png
#
#
# working on img  gamma_corr 147.png
#
#
# working on img  gamma_corr 148.png
#
#
# working on img  gamma_corr 149.png
#
#
# working on img  gamma_corr 150.png
#
#
# working on img  gamma_corr 151.png
#
#
# working on img  gamma_corr 152.png
#
#
# working on img  gamma_corr 153.png
#
#
# working on img  gamma_corr 154.png
#
#
# working on img  gamma_corr 155.png
#
#
# working on img  gamma_corr 156.png
#
#
# working on img  gamma_corr 157.png
#
#
# working on img  gamma_corr 158.png
#
#
# working on img  gamma_corr 159.png
#
#
# working on img  gamma_corr 160.png
#
#
# working on img  gamma_corr 161.png
#
#
# working on img  gamma_corr 162.png
#
#
# working on img  gamma_corr 163.png
#
#
# working on img  gamma_corr 164.png
#
#
# working on img  gamma_corr 165.png
#
#
# working on img  gamma_corr 166.png
#
#
# working on img  gamma_corr 167.png
#
#
# working on img  gamma_corr 168.png
#
#
# working on img  gamma_corr 169.png
#
#
# working on img  gamma_corr 170.png
#
#
# working on img  gamma_corr 171.png
#
#
# working on img  gamma_corr 172.png
#
#
# working on img  gamma_corr 173.png
#
#
# working on img  gamma_corr 174.png
#
#
# working on img  gamma_corr 175.png
#
#
# working on img  gamma_corr 176.png
#
#
# working on img  gamma_corr 177.png
#
#
# working on img  gamma_corr 178.png
#
#
# working on img  gamma_corr 179.png
#
#
# working on img  gamma_corr 180.png
#
#
# working on img  gamma_corr 181.png
#
#
# working on img  gamma_corr 182.png
#
#
# working on img  gamma_corr 183.png
#
#
# working on img  gamma_corr 184.png
#
#
# working on img  gamma_corr 185.png
#
#
# working on img  gamma_corr 186.png
#
#
# working on img  gamma_corr 187.png
#
#
# working on img  gamma_corr 188.png
#
#
# working on img  gamma_corr 189.png
#
#
# working on img  gamma_corr 190.png
#
#
# working on img  gamma_corr 191.png
#
#
# working on img  gamma_corr 192.png
#
#
# working on img  gamma_corr 193.png
#
#
# working on img  gamma_corr 194.png
#
#
# working on img  gamma_corr 195.png
#
#
# working on img  gamma_corr 196.png
#
#
# working on img  gamma_corr 197.png
#
#
# working on img  gamma_corr 198.png
#
#
# working on img  gamma_corr 199.png
#
#
# working on img  gamma_corr 200.png
#
#
# working on img  gamma_corr 201.png
#
#
# working on img  gamma_corr 202.png
#
#
# working on img  gamma_corr 203.png
#
#
# working on img  gamma_corr 204.png
#
#
# working on img  gamma_corr 205.png
#
#
# working on img  gamma_corr 206.png
#
#
# working on img  gamma_corr 207.png
#
#
# working on img  gamma_corr 208.png
#
#
# working on img  gamma_corr 209.png
#
#
# working on img  gamma_corr 210.png
#
#
# working on img  gamma_corr 211.png
#
#
# working on img  gamma_corr 212.png
#
#
# working on img  gamma_corr 213.png
#
#
# working on img  gamma_corr 214.png
#
#
# working on img  gamma_corr 215.png
#
#
# working on img  gamma_corr 216.png
#
#
# working on img  gamma_corr 217.png
#
#
# working on img  gamma_corr 218.png
#
#
# working on img  gamma_corr 219.png
#
#
# working on img  gamma_corr 220.png
#
#
# working on img  gamma_corr 221.png
#
#
# working on img  gamma_corr 222.png
#
#
# working on img  gamma_corr 223.png
#
#
# working on img  gamma_corr 224.png
#
#
# working on img  gamma_corr 225.png
#
#
# working on img  gamma_corr 226.png
#
#
# working on img  gamma_corr 227.png
#
#
# working on img  gamma_corr 228.png
#
#
# working on img  gamma_corr 229.png
#
#
# working on img  gamma_corr 230.png
#
#
# working on img  gamma_corr 231.png
#
#
# working on img  gamma_corr 232.png
#
#
# working on img  gamma_corr 233.png
#
#
# working on img  gamma_corr 234.png
#
#
# working on img  gamma_corr 235.png
#
#
# working on img  gamma_corr 236.png
#
#
# working on img  gamma_corr 237.png
#
#
# working on img  gamma_corr 238.png
#
#
# working on img  gamma_corr 239.png
#
#
# working on img  gamma_corr 240.png
#
#
# working on img  gamma_corr 241.png
#
#
# working on img  gamma_corr 242.png
#
#
# working on img  gamma_corr 243.png
#
#
# working on img  gamma_corr 244.png
#
#
# working on img  gamma_corr 245.png
#
#
# working on img  gamma_corr 246.png
#
#
# working on img  gamma_corr 247.png
#
#
# working on img  gamma_corr 248.png
#
#
# working on img  gamma_corr 249.png
#
#
# working on img  gamma_corr 250.png
#
#
# working on img  gamma_corr 251.png
#
#
# working on img  gamma_corr 252.png
#
#
# working on img  gamma_corr 253.png
#
#
# working on img  gamma_corr 254.png
#
#
# working on img  gamma_corr 255.png
#
#
# working on img  gamma_corr 256.png
#
#
# working on img  gamma_corr 257.png
#
#
# working on img  gamma_corr 258.png
#
#
# working on img  gamma_corr 259.png
#
#
# working on img  gamma_corr 260.png
#
#
# working on img  gamma_corr 261.png
#
#
# working on img  gamma_corr 262.png
#
#
# working on img  gamma_corr 263.png
#
#
# working on img  gamma_corr 264.png
#
#
# working on img  gamma_corr 265.png
#
#
# working on img  gamma_corr 266.png
#
#
# working on img  gamma_corr 267.png
#
#
# working on img  gamma_corr 268.png
#
#
# working on img  gamma_corr 269.png
#
#
# working on img  gamma_corr 270.png
#
#
# working on img  gamma_corr 271.png
#
#
# working on img  gamma_corr 272.png
#
#
# working on img  gamma_corr 273.png
#
#
# working on img  gamma_corr 274.png
#
#
# working on img  gamma_corr 275.png
#
#
# working on img  gamma_corr 276.png
#
#
# working on img  gamma_corr 277.png
#
#
# working on img  gamma_corr 278.png
#
#
# working on img  gamma_corr 279.png
#
#
# working on img  gamma_corr 280.png
#
#
# working on img  gamma_corr 281.png
#
#
# working on img  gamma_corr 282.png
#
#
# working on img  gamma_corr 283.png
#
#
# working on img  gamma_corr 284.png
#
#
# working on img  gamma_corr 285.png
#
#
# working on img  gamma_corr 286.png
#
#
# working on img  gamma_corr 287.png
#
#
# working on img  gamma_corr 288.png
#
#
# working on img  gamma_corr 289.png
#
#
# working on img  gamma_corr 290.png
#
#
# working on img  gamma_corr 291.png
#
#
# working on img  gamma_corr 292.png
#
#
# working on img  gamma_corr 293.png
#
#
# working on img  gamma_corr 294.png
#
#
# working on img  gamma_corr 295.png
#
#
# working on img  gamma_corr 296.png
#
#
# working on img  gamma_corr 297.png
#
#
# working on img  gamma_corr 298.png
#
#
# working on img  gamma_corr 299.png
#
#
# working on img  gamma_corr 300.png
#
#
# working on img  gamma_corr 301.png
#
#
# working on img  gamma_corr 302.png
#
#
# working on img  gamma_corr 303.png
#
#
# working on img  gamma_corr 304.png
#
#
# working on img  gamma_corr 305.png
#
#
# working on img  gamma_corr 306.png
#
#
# working on img  gamma_corr 307.png
#
#
# working on img  gamma_corr 308.png
#
#
# working on img  gamma_corr 309.png
#
#
# working on img  gamma_corr 310.png
#
#
# working on img  gamma_corr 311.png
#
#
# working on img  gamma_corr 312.png
#
#
# working on img  gamma_corr 313.png
#
#
# working on img  gamma_corr 314.png
#
#
# working on img  gamma_corr 315.png
#
#
# working on img  gamma_corr 316.png
#
#
# working on img  gamma_corr 317.png
#
#
# working on img  gamma_corr 318.png
#
#
# working on img  gamma_corr 319.png
#
#
# working on img  gamma_corr 320.png
#
#
# working on img  gamma_corr 321.png
#
#
# working on img  gamma_corr 322.png
#
#
# working on img  gamma_corr 323.png
#
#
# working on img  gamma_corr 324.png
#
#
# working on img  gamma_corr 325.png
#
#
# working on img  gamma_corr 326.png
#
#
# working on img  gamma_corr 327.png
#
#
# working on img  gamma_corr 328.png
#
#
# working on img  gamma_corr 329.png
#
#
# working on img  gamma_corr 330.png
#
#
# working on img  gamma_corr 331.png
#
#
# working on img  gamma_corr 332.png
#
#
# working on img  gamma_corr 333.png
#
#
# working on img  gamma_corr 334.png
#
#
# working on img  gamma_corr 335.png
#
#
# working on img  gamma_corr 336.png
#
#
# working on img  gamma_corr 337.png
#
#
# working on img  gamma_corr 338.png
#
#
# working on img  gamma_corr 339.png
#
#
# working on img  gamma_corr 340.png
#
#
# working on img  gamma_corr 341.png
#
#
# working on img  gamma_corr 342.png
#
#
# working on img  gamma_corr 343.png
#
#
# working on img  gamma_corr 344.png
#
#
# working on img  gamma_corr 345.png
#
#
# working on img  gamma_corr 346.png
#
#
# working on img  gamma_corr 347.png
#
#
# working on img  gamma_corr 348.png
#
#
# working on img  gamma_corr 349.png
#
#
# working on img  gamma_corr 350.png
#
#
# working on img  gamma_corr 351.png
#
#
# working on img  gamma_corr 352.png
#
#
# working on img  gamma_corr 353.png
#
#
# working on img  gamma_corr 354.png
#
#
# working on img  gamma_corr 355.png
#
#
# working on img  gamma_corr 356.png
#
#
# working on img  gamma_corr 357.png
#
#
# working on img  gamma_corr 358.png
#
#
# working on img  gamma_corr 359.png
#
#
# working on img  gamma_corr 360.png
#
#
# working on img  gamma_corr 361.png
#
#
# working on img  gamma_corr 362.png
#
#
# working on img  gamma_corr 363.png
#
#
# working on img  gamma_corr 364.png
#
#
# working on img  gamma_corr 365.png
#
#
# working on img  gamma_corr 366.png
#
#
# working on img  gamma_corr 367.png
#
#
# working on img  gamma_corr 368.png
#
#
# working on img  gamma_corr 369.png
#
#
# working on img  gamma_corr 370.png
#
#
# working on img  gamma_corr 371.png
#
#
# working on img  gamma_corr 372.png
#
#
# working on img  gamma_corr 373.png
#
#
# working on img  gamma_corr 374.png
#
#
# working on img  gamma_corr 375.png
#
#
# working on img  gamma_corr 376.png
#
#
# working on img  gamma_corr 377.png
#
#
# working on img  gamma_corr 378.png
#
#
# working on img  gamma_corr 379.png
#
#
# working on img  gamma_corr 380.png
#
#
# working on img  gamma_corr 381.png
#
#
# working on img  gamma_corr 382.png
#
#
# working on img  gamma_corr 383.png
#
#
# working on img  gamma_corr 384.png
#
#
# working on img  gamma_corr 385.png
#
#
# working on img  gamma_corr 386.png
#
#
# working on img  gamma_corr 387.png
#
#
# working on img  gamma_corr 388.png
#
#
# working on img  gamma_corr 389.png
#
#
# working on img  gamma_corr 390.png
#
#
# working on img  gamma_corr 391.png
#
#
# working on img  gamma_corr 392.png
#
#
# working on img  gamma_corr 393.png
#
#
# working on img  gamma_corr 394.png
#
#
# working on img  gamma_corr 395.png
#
#
# working on img  gamma_corr 396.png
#
#
# working on img  gamma_corr 397.png
#
#
# working on img  gamma_corr 398.png
#
#
# working on img  gamma_corr 399.png
#
#
# working on img  gamma_corr 400.png
#
#
# working on img  gamma_corr 401.png
#
#
# working on img  gamma_corr 402.png
#
#
# working on img  gamma_corr 403.png
#
#
# working on img  gamma_corr 404.png
#
#
# working on img  gamma_corr 405.png
#
#
# working on img  gamma_corr 406.png
#
#
# working on img  gamma_corr 407.png
#
#
# working on img  gamma_corr 408.png
#
#
# working on img  gamma_corr 409.png
#
#
# working on img  gamma_corr 410.png
#
#
# working on img  gamma_corr 411.png
#
#
# working on img  gamma_corr 412.png
#
#
# working on img  gamma_corr 413.png
#
#
# working on img  gamma_corr 414.png
#
#
# working on img  gamma_corr 415.png
#
#
# working on img  gamma_corr 416.png
#
#
# working on img  gamma_corr 417.png
#
#
# working on img  gamma_corr 418.png
#
#
# working on img  gamma_corr 419.png
#
#
# working on img  gamma_corr 420.png
#
#
# working on img  gamma_corr 421.png
#
#
# working on img  gamma_corr 422.png
#
#
# working on img  gamma_corr 423.png
#
#
# working on img  gamma_corr 424.png
#
#
# working on img  gamma_corr 425.png
#
#
# working on img  gamma_corr 426.png
#
#
# working on img  gamma_corr 427.png
#
#
# working on img  gamma_corr 428.png
#
#
# working on img  gamma_corr 429.png
#
#
# working on img  gamma_corr 430.png
#
#
# working on img  gamma_corr 431.png
#
#
# working on img  gamma_corr 432.png
#
#
# working on img  gamma_corr 433.png
#
#
# working on img  gamma_corr 434.png
#
#
# working on img  gamma_corr 435.png
#
#
# working on img  gamma_corr 436.png
#
#
# working on img  gamma_corr 437.png
#
#
# working on img  gamma_corr 438.png
#
#
# working on img  gamma_corr 439.png
#
#
# working on img  gamma_corr 440.png
#
#
# working on img  gamma_corr 441.png
#
#
# working on img  gamma_corr 442.png
#
#
# working on img  gamma_corr 443.png
#
#
# working on img  gamma_corr 444.png
#
#
# working on img  gamma_corr 445.png
#
#
# working on img  gamma_corr 446.png
#
#
# working on img  gamma_corr 447.png
#
#
# working on img  gamma_corr 448.png
#
#
# working on img  gamma_corr 449.png
#
#
# working on img  gamma_corr 450.png
#
#
# working on img  gamma_corr 451.png
#
#
# working on img  gamma_corr 452.png
#
#
# working on img  gamma_corr 453.png
#
#
# working on img  gamma_corr 454.png
#
#
# working on img  gamma_corr 455.png
#
#
# working on img  gamma_corr 456.png
#
#
# working on img  gamma_corr 457.png
#
#
# working on img  gamma_corr 458.png
#
#
# working on img  gamma_corr 459.png
#
#
# working on img  gamma_corr 460.png
#
#
# working on img  gamma_corr 461.png
#
#
# working on img  gamma_corr 462.png
#
#
# working on img  gamma_corr 463.png
#
#
# working on img  gamma_corr 464.png
#
#
# working on img  gamma_corr 465.png
#
#
# working on img  gamma_corr 466.png
#
#
# working on img  gamma_corr 467.png
#
#
# working on img  gamma_corr 468.png
#
#
# working on img  gamma_corr 469.png
#
#
# working on img  gamma_corr 470.png
#
#
# working on img  gamma_corr 471.png
#
#
# working on img  gamma_corr 472.png
#
#
# working on img  gamma_corr 473.png
#
#
# working on img  gamma_corr 474.png
#
#
# working on img  gamma_corr 475.png
#
#
# working on img  gamma_corr 476.png
#
#
# working on img  gamma_corr 477.png
#
#
# working on img  gamma_corr 478.png
#
#
# working on img  gamma_corr 479.png
#
#
#
#
#
#
# black images found:  0 out of total image :  480

# %%
####################### feature extraction###################




#############give directory 

dirr1= r'/content/drive/MyDrive/Breast Cancer/Final Work/Dataset/Grade_3' #### source folder

csv=r'/content/drive/MyDrive/Breast Cancer/Final Work/CSV File/LBP_Grade_3.csv' ### csv save path
### must change csv path

c=1 ### c=class 1=0 or class 2=1  

#####################################################################################################



black=0
j=0
df1 = pd.DataFrame(columns=['class', 'Area', 'PA_ratio', 'Solidity', 'Circularity', 'EquivDiameter', 'ConvexArea', 'Extent', 'FilledArea', 'Major axis length', 'Minor axis length', 'Mean', 'Standard Deviation', 'Shannon_Entropy', 'Glcm_entropy', 'Skewness', 'kurtosis','lbp_energy','lbp_entropy','gabor_energy','gabor_entropy'])

onlyfiles = next(os.walk(dirr1))[2] #dir is your directory path as string
print(len(onlyfiles))



for i in os.listdir(dirr1):
    path = os.path.join(dirr1,i)
    im = io.imread(path)
    height = im.shape[0]
    width = im.shape[1]
    print('working on img ',i)
    props=sk.measure.regionprops(im)
    
    
    if len(props)!=0:
        pr=[]
        for prop in props: 
            pr.append(prop.area)
        num = np.array(pr)
        a=props[np.argmax(num)]
        
        imgcv = cv2.imread(path)
        gray = cv2.cvtColor(imgcv,cv2.COLOR_BGR2GRAY)
        ret, thresh = cv2.threshold(gray,0,255,cv2.THRESH_BINARY)
        cv2.waitKey(0)
        cv2.destroyAllWindows()
        ave = cv2.mean(thresh)[0]/255
        area = ave*height*width###########################
        try:
            image=skimage.io.imread(path,as_gray=True)
            thresh = threshold_otsu(image)
            binary = image > thresh
            perimeter=measure.perimeter(binary)################


            PA_ratio=round(perimeter/area,4)
            EquivDiameter=round(sqrt(4*area/math.pi),4)
            Circularity=round((4*area*math.pi)/(perimeter*perimeter),4)
            ConvexArea=round(a.convex_area,4)

        except:
            
            print('black found \n')
            black+=1
      
            continue    
       









        Extent=round(a.extent,4)
        Solidity=round(area/ConvexArea,4)
        FilledArea=round(a.filled_area,4)
        maj_ax_le=round(a.major_axis_length,4)
        min_ax_le=round(a.minor_axis_length,4)
        #LS_ratio=round(maj_ax_le/min_ax_le,4)
        EulerNumber=round(a.euler_number,4)



        image=Image.open(path)
        pixels=asarray(image)
        # convert from integers to floats
        pixels=pixels.astype('float32')
        # calculate global mean
        mean=round(pixels.mean(),3)

        pixels=asarray(image)
        # convert from integers to floats
        pixels=pixels.astype('float32')
        # calculate global mean and standard deviation
        std=round(pixels.std(),3)

        #print('Standard Deviation: %.3f' % (std))
        sha_entropy=round(skimage.measure.shannon_entropy(image),4)


        #LBP & Gabor
        img_gray = image.convert('L') 
        img_arr = np.array(img_gray)
        feat_lbp = local_binary_pattern(img_arr,8,1,'uniform') #Radius = 1, No. of neighbours = 8
        feat_lbp = np.uint8((feat_lbp/feat_lbp.max())*255)
        lbp_hist,_ = np.histogram(feat_lbp,8)
        lbp_hist = np.array(lbp_hist,dtype=float)
        lbp_prob = np.divide(lbp_hist,np.sum(lbp_hist))
        lbp_energy = np.sum(lbp_prob**2)
        lbp_entropy = -np.sum(np.multiply(lbp_prob,np.log2(lbp_prob)))

        gaborFilt_real,gaborFilt_imag = gabor(img_arr,frequency=0.6)
        gaborFilt = (gaborFilt_real**2+gaborFilt_imag**2)//2
        gabor_hist,_ = np.histogram(gaborFilt,8)
        gabor_hist = np.array(gabor_hist,dtype=float)
        gabor_prob = np.divide(gabor_hist,np.sum(gabor_hist))
        gabor_energy = np.sum(gabor_prob**2)
        gabor_entropy = -np.sum(np.multiply(gabor_prob,np.log2(gabor_prob)))

        


        rgbImg=io.imread(path)
        grayImg=img_as_ubyte(color.rgb2gray(rgbImg))
        distances=[1,2,3]
        angles=[0,np.pi/4,np.pi/2,3*np.pi/4]
        properties=['energy','homogeneity']
        glcm=greycomatrix(grayImg,distances=distances,angles=angles,symmetric=True,normed=True)
        glcm_entropy=round(-np.sum(glcm*np.log2(glcm+(glcm==0))),4)
        im=cv2.imread(path)
        colon_number=0
        Skewness=round(skew(im.reshape(-1,3)[:,colon_number]),4)
        Kurtosis=round(kurtosis(im.reshape(-1,3)[:,colon_number]),4)
        #df1.loc[j] =list(area)+list(PA_ratio)+list(Solidity)+list(Circularity)+list(EquivDiameter)+list(ConvexArea)+list(Extent)+list(FilledArea)+list(maj_ax_le)+list(min_ax_le)+list(mean)+list(std)+list(sha_entropy)+list(glcm_entropy)+list(Skewness)+list(Kurtosis)
        df1.loc[j]=({'class':c,'Area':area,
                          'PA_ratio':PA_ratio,
                          'Solidity':Solidity,
                          'Circularity':Circularity,
                          'EquivDiameter':EquivDiameter,
                          'ConvexArea':ConvexArea,
                          'Extent':Extent,
                          'FilledArea':FilledArea,
                          'Major axis length':maj_ax_le,
                          'Minor axis length':min_ax_le,
                          #'LS_ Ratio':[LS_ratio],
                          'Mean':mean,
                          'Standard Deviation':std,
                          'Shannon_Entropy':sha_entropy,
                          'Glcm_entropy':glcm_entropy,
                          'Skewness':Skewness,
                          'kurtosis':Kurtosis,
                          'lbp_energy':lbp_energy,
                          'lbp_entropy':lbp_entropy,
                          'gabor_energy':gabor_energy,
                          'gabor_entropy':gabor_entropy})

        j+=1
    else:
        print('black found \n')
        black+=1
    print('\n')
      
print('\n\n\n') 
print('black images found: ',black, 'out of total image : ',len(onlyfiles), )    
print('\n\n\n\n\n\n')    
    
    
    
    
frames = df1


############################################### give directy to save csv file

#roidata_set = pd.concat(frames)
frames.to_csv(csv,index=False)### give train.csv path
#print(frames)

###############################################################################


######## after completing train set give me an ss of the output that will be printed below... do the same for val and test also.
# Out:
# 361
# working on img  gamma_corr 0.png
#
#
# working on img  gamma_corr 1.png
#
#
# working on img  gamma_corr 2.png
#
#
# working on img  gamma_corr 3.png
#
#
# working on img  gamma_corr 4.png
#
#
# working on img  gamma_corr 5.png
#
#
# working on img  gamma_corr 6.png
#
#
# working on img  gamma_corr 7.png
#
#
# working on img  gamma_corr 8.png
#
#
# working on img  gamma_corr 9.png
#
#
# working on img  gamma_corr 10.png
#
#
# working on img  gamma_corr 11.png
#
#
# working on img  gamma_corr 12.png
#
#
# working on img  gamma_corr 13.png
#
#
# working on img  gamma_corr 14.png
#
#
# working on img  gamma_corr 15.png
#
#
# working on img  gamma_corr 16.png
#
#
# working on img  gamma_corr 17.png
#
#
# working on img  gamma_corr 18.png
#
#
# working on img  gamma_corr 19.png
#
#
# working on img  gamma_corr 20.png
#
#
# working on img  gamma_corr 21.png
#
#
# working on img  gamma_corr 22.png
#
#
# working on img  gamma_corr 23.png
#
#
# working on img  gamma_corr 24.png
#
#
# working on img  gamma_corr 25.png
#
#
# working on img  gamma_corr 26.png
#
#
# working on img  gamma_corr 27.png
#
#
# working on img  gamma_corr 28.png
#
#
# working on img  gamma_corr 29.png
#
#
# working on img  gamma_corr 30.png
#
#
# working on img  gamma_corr 31.png
#
#
# working on img  gamma_corr 32.png
#
#
# working on img  gamma_corr 33.png
#
#
# working on img  gamma_corr 34.png
#
#
# working on img  gamma_corr 35.png
#
#
# working on img  gamma_corr 36.png
#
#
# working on img  gamma_corr 37.png
#
#
# working on img  gamma_corr 38.png
#
#
# working on img  gamma_corr 39.png
#
#
# working on img  gamma_corr 40.png
#
#
# working on img  gamma_corr 41.png
#
#
# working on img  gamma_corr 42.png
#
#
# working on img  gamma_corr 43.png
#
#
# working on img  gamma_corr 44.png
#
#
# working on img  gamma_corr 45.png
#
#
# working on img  gamma_corr 46.png
#
#
# working on img  gamma_corr 47.png
#
#
# working on img  gamma_corr 48.png
#
#
# working on img  gamma_corr 49.png
#
#
# working on img  gamma_corr 50.png
#
#
# working on img  gamma_corr 51.png
#
#
# working on img  gamma_corr 52.png
#
#
# working on img  gamma_corr 53.png
#
#
# working on img  gamma_corr 54.png
#
#
# working on img  gamma_corr 55.png
#
#
# working on img  gamma_corr 56.png
#
#
# working on img  gamma_corr 57.png
#
#
# working on img  gamma_corr 58.png
#
#
# working on img  gamma_corr 59.png
#
#
# working on img  gamma_corr 60.png
#
#
# working on img  gamma_corr 61.png
#
#
# working on img  gamma_corr 62.png
#
#
# working on img  gamma_corr 63.png
#
#
# working on img  gamma_corr 64.png
#
#
# working on img  gamma_corr 65.png
#
#
# working on img  gamma_corr 66.png
#
#
# working on img  gamma_corr 67.png
#
#
# working on img  gamma_corr 68.png
#
#
# working on img  gamma_corr 69.png
#
#
# working on img  gamma_corr 70.png
#
#
# working on img  gamma_corr 71.png
#
#
# working on img  gamma_corr 72.png
#
#
# working on img  gamma_corr 73.png
#
#
# working on img  gamma_corr 74.png
#
#
# working on img  gamma_corr 75.png
#
#
# working on img  gamma_corr 76.png
#
#
# working on img  gamma_corr 77.png
#
#
# working on img  gamma_corr 78.png
#
#
# working on img  gamma_corr 79.png
#
#
# working on img  gamma_corr 80.png
#
#
# working on img  gamma_corr 81.png
#
#
# working on img  gamma_corr 82.png
#
#
# working on img  gamma_corr 83.png
#
#
# working on img  gamma_corr 84.png
#
#
# working on img  gamma_corr 85.png
#
#
# working on img  gamma_corr 86.png
#
#
# working on img  gamma_corr 87.png
#
#
# working on img  gamma_corr 88.png
#
#
# working on img  gamma_corr 89.png
#
#
# working on img  gamma_corr 90.png
#
#
# working on img  gamma_corr 91.png
#
#
# working on img  gamma_corr 92.png
#
#
# working on img  gamma_corr 93.png
#
#
# working on img  gamma_corr 94.png
#
#
# working on img  gamma_corr 95.png
#
#
# working on img  gamma_corr 96.png
#
#
# working on img  gamma_corr 97.png
#
#
# working on img  gamma_corr 98.png
#
#
# working on img  gamma_corr 99.png
#
#
# working on img  gamma_corr 100.png
#
#
# working on img  gamma_corr 101.png
#
#
# working on img  gamma_corr 102.png
#
#
# working on img  gamma_corr 103.png
#
#
# working on img  gamma_corr 104.png
#
#
# working on img  gamma_corr 105.png
#
#
# working on img  gamma_corr 106.png
#
#
# working on img  gamma_corr 107.png
#
#
# working on img  gamma_corr 108.png
#
#
# working on img  gamma_corr 109.png
#
#
# working on img  gamma_corr 110.png
#
#
# working on img  gamma_corr 111.png
#
#
# working on img  gamma_corr 112.png
#
#
# working on img  gamma_corr 113.png
#
#
# working on img  gamma_corr 114.png
#
#
# working on img  gamma_corr 115.png
#
#
# working on img  gamma_corr 116.png
#
#
# working on img  gamma_corr 117.png
#
#
# working on img  gamma_corr 118.png
#
#
# working on img  gamma_corr 119.png
#
#
# working on img  gamma_corr 120.png
#
#
# working on img  gamma_corr 121.png
#
#
# working on img  gamma_corr 122.png
#
#
# working on img  gamma_corr 123.png
#
#
# working on img  gamma_corr 124.png
#
#
# working on img  gamma_corr 125.png
#
#
# working on img  gamma_corr 126.png
#
#
# working on img  gamma_corr 127.png
#
#
# working on img  gamma_corr 128.png
#
#
# working on img  gamma_corr 129.png
#
#
# working on img  gamma_corr 130.png
#
#
# working on img  gamma_corr 131.png
#
#
# working on img  gamma_corr 132.png
#
#
# working on img  gamma_corr 133.png
#
#
# working on img  gamma_corr 134.png
#
#
# working on img  gamma_corr 135.png
#
#
# working on img  gamma_corr 136.png
#
#
# working on img  gamma_corr 137.png
#
#
# working on img  gamma_corr 138.png
#
#
# working on img  gamma_corr 139.png
#
#
# working on img  gamma_corr 140.png
#
#
# working on img  gamma_corr 141.png
#
#
# working on img  gamma_corr 142.png
#
#
# working on img  gamma_corr 143.png
#
#
# working on img  gamma_corr 144.png
#
#
# working on img  gamma_corr 145.png
#
#
# working on img  gamma_corr 146.png
#
#
# working on img  gamma_corr 147.png
#
#
# working on img  gamma_corr 148.png
#
#
# working on img  gamma_corr 149.png
#
#
# working on img  gamma_corr 150.png
#
#
# working on img  gamma_corr 151.png
#
#
# working on img  gamma_corr 152.png
#
#
# working on img  gamma_corr 153.png
#
#
# working on img  gamma_corr 154.png
#
#
# working on img  gamma_corr 155.png
#
#
# working on img  gamma_corr 156.png
#
#
# working on img  gamma_corr 157.png
#
#
# working on img  gamma_corr 158.png
#
#
# working on img  gamma_corr 159.png
#
#
# working on img  gamma_corr 160.png
#
#
# working on img  gamma_corr 161.png
#
#
# working on img  gamma_corr 162.png
#
#
# working on img  gamma_corr 163.png
#
#
# working on img  gamma_corr 164.png
#
#
# working on img  gamma_corr 165.png
#
#
# working on img  gamma_corr 166.png
#
#
# working on img  gamma_corr 167.png
#
#
# working on img  gamma_corr 168.png
#
#
# working on img  gamma_corr 169.png
#
#
# working on img  gamma_corr 170.png
#
#
# working on img  gamma_corr 171.png
#
#
# working on img  gamma_corr 172.png
#
#
# working on img  gamma_corr 173.png
#
#
# working on img  gamma_corr 174.png
#
#
# working on img  gamma_corr 175.png
#
#
# working on img  gamma_corr 176.png
#
#
# working on img  gamma_corr 177.png
#
#
# working on img  gamma_corr 178.png
#
#
# working on img  gamma_corr 179.png
#
#
# working on img  gamma_corr 180.png
#
#
# working on img  gamma_corr 181.png
#
#
# working on img  gamma_corr 182.png
#
#
# working on img  gamma_corr 183.png
#
#
# working on img  gamma_corr 184.png
#
#
# working on img  gamma_corr 185.png
#
#
# working on img  gamma_corr 186.png
#
#
# working on img  gamma_corr 187.png
#
#
# working on img  gamma_corr 188.png
#
#
# working on img  gamma_corr 189.png
#
#
# working on img  gamma_corr 190.png
#
#
# working on img  gamma_corr 191.png
#
#
# working on img  gamma_corr 192.png
#
#
# working on img  gamma_corr 193.png
#
#
# working on img  gamma_corr 194.png
#
#
# working on img  gamma_corr 195.png
#
#
# working on img  gamma_corr 196.png
#
#
# working on img  gamma_corr 197.png
#
#
# working on img  gamma_corr 198.png
#
#
# working on img  gamma_corr 199.png
#
#
# working on img  gamma_corr 200.png
#
#
# working on img  gamma_corr 201.png
#
#
# working on img  gamma_corr 202.png
#
#
# working on img  gamma_corr 203.png
#
#
# working on img  gamma_corr 204.png
#
#
# working on img  gamma_corr 205.png
#
#
# working on img  gamma_corr 206.png
#
#
# working on img  gamma_corr 207.png
#
#
# working on img  gamma_corr 208.png
#
#
# working on img  gamma_corr 209.png
#
#
# working on img  gamma_corr 210.png
#
#
# working on img  gamma_corr 211.png
#
#
# working on img  gamma_corr 212.png
#
#
# working on img  gamma_corr 213.png
#
#
# working on img  gamma_corr 214.png
#
#
# working on img  gamma_corr 215.png
#
#
# working on img  gamma_corr 216.png
#
#
# working on img  gamma_corr 217.png
#
#
# working on img  gamma_corr 218.png
#
#
# working on img  gamma_corr 219.png
#
#
# working on img  gamma_corr 220.png
#
#
# working on img  gamma_corr 221.png
#
#
# working on img  gamma_corr 222.png
#
#
# working on img  gamma_corr 223.png
#
#
# working on img  gamma_corr 224.png
#
#
# working on img  gamma_corr 225.png
#
#
# working on img  gamma_corr 226.png
#
#
# working on img  gamma_corr 227.png
#
#
# working on img  gamma_corr 228.png
#
#
# working on img  gamma_corr 229.png
#
#
# working on img  gamma_corr 230.png
#
#
# working on img  gamma_corr 231.png
#
#
# working on img  gamma_corr 232.png
#
#
# working on img  gamma_corr 233.png
#
#
# working on img  gamma_corr 234.png
#
#
# working on img  gamma_corr 235.png
#
#
# working on img  gamma_corr 236.png
#
#
# working on img  gamma_corr 237.png
#
#
# working on img  gamma_corr 238.png
#
#
# working on img  gamma_corr 239.png
#
#
# working on img  gamma_corr 240.png
#
#
# working on img  gamma_corr 241.png
#
#
# working on img  gamma_corr 242.png
#
#
# working on img  gamma_corr 243.png
#
#
# working on img  gamma_corr 244.png
#
#
# working on img  gamma_corr 245.png
#
#
# working on img  gamma_corr 246.png
#
#
# working on img  gamma_corr 247.png
#
#
# working on img  gamma_corr 248.png
#
#
# working on img  gamma_corr 249.png
#
#
# working on img  gamma_corr 250.png
#
#
# working on img  gamma_corr 251.png
#
#
# working on img  gamma_corr 252.png
#
#
# working on img  gamma_corr 253.png
#
#
# working on img  gamma_corr 254.png
#
#
# working on img  gamma_corr 255.png
#
#
# working on img  gamma_corr 256.png
#
#
# working on img  gamma_corr 257.png
#
#
# working on img  gamma_corr 258.png
#
#
# working on img  gamma_corr 259.png
#
#
# working on img  gamma_corr 260.png
#
#
# working on img  gamma_corr 261.png
#
#
# working on img  gamma_corr 262.png
#
#
# working on img  gamma_corr 263.png
#
#
# working on img  gamma_corr 264.png
#
#
# working on img  gamma_corr 265.png
#
#
# working on img  gamma_corr 266.png
#
#
# working on img  gamma_corr 267.png
#
#
# working on img  gamma_corr 268.png
#
#
# working on img  gamma_corr 269.png
#
#
# working on img  gamma_corr 270.png
#
#
# working on img  gamma_corr 271.png
#
#
# working on img  gamma_corr 272.png
#
#
# working on img  gamma_corr 273.png
#
#
# working on img  gamma_corr 274.png
#
#
# working on img  gamma_corr 275.png
#
#
# working on img  gamma_corr 276.png
#
#
# working on img  gamma_corr 277.png
#
#
# working on img  gamma_corr 278.png
#
#
# working on img  gamma_corr 279.png
#
#
# working on img  gamma_corr 280.png
#
#
# working on img  gamma_corr 281.png
#
#
# working on img  gamma_corr 282.png
#
#
# working on img  gamma_corr 283.png
#
#
# working on img  gamma_corr 284.png
#
#
# working on img  gamma_corr 285.png
#
#
# working on img  gamma_corr 286.png
#
#
# working on img  gamma_corr 287.png
#
#
# working on img  gamma_corr 288.png
#
#
# working on img  gamma_corr 289.png
#
#
# working on img  gamma_corr 290.png
#
#
# working on img  gamma_corr 291.png
#
#
# working on img  gamma_corr 292.png
#
#
# working on img  gamma_corr 293.png
#
#
# working on img  gamma_corr 294.png
#
#
# working on img  gamma_corr 295.png
#
#
# working on img  gamma_corr 296.png
#
#
# working on img  gamma_corr 297.png
#
#
# working on img  gamma_corr 298.png
#
#
# working on img  gamma_corr 299.png
#
#
# working on img  gamma_corr 300.png
#
#
# working on img  gamma_corr 301.png
#
#
# working on img  gamma_corr 302.png
#
#
# working on img  gamma_corr 303.png
#
#
# working on img  gamma_corr 304.png
#
#
# working on img  gamma_corr 305.png
#
#
# working on img  gamma_corr 306.png
#
#
# working on img  gamma_corr 307.png
#
#
# working on img  gamma_corr 308.png
#
#
# working on img  gamma_corr 309.png
#
#
# working on img  gamma_corr 310.png
#
#
# working on img  gamma_corr 311.png
#
#
# working on img  gamma_corr 312.png
#
#
# working on img  gamma_corr 313.png
#
#
# working on img  gamma_corr 314.png
#
#
# working on img  gamma_corr 315.png
#
#
# working on img  gamma_corr 316.png
#
#
# working on img  gamma_corr 317.png
#
#
# working on img  gamma_corr 318.png
#
#
# working on img  gamma_corr 319.png
#
#
# working on img  gamma_corr 320.png
#
#
# working on img  gamma_corr 321.png
#
#
# working on img  gamma_corr 322.png
#
#
# working on img  gamma_corr 323.png
#
#
# working on img  gamma_corr 324.png
#
#
# working on img  gamma_corr 325.png
#
#
# working on img  gamma_corr 326.png
#
#
# working on img  gamma_corr 327.png
#
#
# working on img  gamma_corr 328.png
#
#
# working on img  gamma_corr 329.png
#
#
# working on img  gamma_corr 330.png
#
#
# working on img  gamma_corr 331.png
#
#
# working on img  gamma_corr 332.png
#
#
# working on img  gamma_corr 333.png
#
#
# working on img  gamma_corr 334.png
#
#
# working on img  gamma_corr 335.png
#
#
# working on img  gamma_corr 336.png
#
#
# working on img  gamma_corr 337.png
#
#
# working on img  gamma_corr 338.png
#
#
# working on img  gamma_corr 339.png
#
#
# working on img  gamma_corr 340.png
#
#
# working on img  gamma_corr 341.png
#
#
# working on img  gamma_corr 342.png
#
#
# working on img  gamma_corr 343.png
#
#
# working on img  gamma_corr 344.png
#
#
# working on img  gamma_corr 345.png
#
#
# working on img  gamma_corr 346.png
#
#
# working on img  gamma_corr 347.png
#
#
# working on img  gamma_corr 348.png
#
#
# working on img  gamma_corr 349.png
#
#
# working on img  gamma_corr 350.png
#
#
# working on img  gamma_corr 351.png
#
#
# working on img  gamma_corr 352.png
#
#
# working on img  gamma_corr 353.png
#
#
# working on img  gamma_corr 354.png
#
#
# working on img  gamma_corr 355.png
#
#
# working on img  gamma_corr 356.png
#
#
# working on img  gamma_corr 357.png
#
#
# working on img  gamma_corr 358.png
#
#
# working on img  gamma_corr 359.png
#
#
# working on img  gamma_corr 360.png
#
#
#
#
#
#
# black images found:  0 out of total image :  361
