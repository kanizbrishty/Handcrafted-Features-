# %%
import numpy as np 
import matplotlib.pyplot as plt
import glob
import cv2
import os
import seaborn as sns
import pandas as pd
from skimage.filters import sobel
from skimage.feature import greycomatrix, greycoprops
from skimage.measure import shannon_entropy

# %% [markdown]
# # **Grade_1**

# %%
print(os.listdir("/content/drive/MyDrive/Breast Cancer/Final Work/Dataset/Grade_1"))
# Out:
# ['gamma_corr 0.png', 'gamma_corr 1.png', 'gamma_corr 2.png', 'gamma_corr 3.png', 'gamma_corr 4.png', 'gamma_corr 5.png', 'gamma_corr 6.png', 'gamma_corr 7.png', 'gamma_corr 8.png', 'gamma_corr 9.png', 'gamma_corr 10.png', 'gamma_corr 11.png', 'gamma_corr 12.png', 'gamma_corr 13.png', 'gamma_corr 14.png', 'gamma_corr 15.png', 'gamma_corr 16.png', 'gamma_corr 17.png', 'gamma_corr 18.png', 'gamma_corr 19.png', 'gamma_corr 20.png', 'gamma_corr 21.png', 'gamma_corr 22.png', 'gamma_corr 23.png', 'gamma_corr 24.png', 'gamma_corr 25.png', 'gamma_corr 26.png', 'gamma_corr 27.png', 'gamma_corr 28.png', 'gamma_corr 29.png', 'gamma_corr 30.png', 'gamma_corr 31.png', 'gamma_corr 32.png', 'gamma_corr 33.png', 'gamma_corr 34.png', 'gamma_corr 35.png', 'gamma_corr 36.png', 'gamma_corr 37.png', 'gamma_corr 38.png', 'gamma_corr 39.png', 'gamma_corr 40.png', 'gamma_corr 41.png', 'gamma_corr 42.png', 'gamma_corr 43.png', 'gamma_corr 44.png', 'gamma_corr 45.png', 'gamma_corr 46.png', 'gamma_corr 47.png',
# ...

# %%
SIZE =224
train_images = []
train_labels = [] 
#for directory_path in glob.glob("cell_images/train/*"):
for directory_path in glob.glob("/content/drive/MyDrive/Breast Cancer/Final Work/Dataset/Grade_1"):
    label = directory_path.split("\\")[-1]
    print(label)
    for img_path in glob.glob(os.path.join(directory_path, "*.png")):
        print(img_path)
        img = cv2.imread(img_path, 0) #Reading color images
        img = cv2.resize(img, (SIZE, SIZE)) #Resize images
        train_images.append(img)
        train_labels.append(label)
        
train_images = np.array(train_images)
train_labels = np.array(train_labels)

#Do exactly the same for test/validation images
# test
test_images = []
test_labels = []
#for directory_path in glob.glob("cell_images/test/*"): 
for directory_path in glob.glob("/content/drive/MyDrive/Breast Cancer/Final Work/Dataset/Grade_1"):
    fruit_label = directory_path.split("\\")[-1]
    for img_path in glob.glob(os.path.join(directory_path, "*.png")):
        img = cv2.imread(img_path, 0)
        img = cv2.resize(img, (SIZE, SIZE))
        test_images.append(img)
        test_labels.append(fruit_label)
        
test_images = np.array(test_images)
test_labels = np.array(test_labels)

#Encode labels from text (folder names) to integers.
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
le.fit(test_labels)
test_labels_encoded = le.transform(test_labels)
le.fit(train_labels)
train_labels_encoded = le.transform(train_labels)

#Split data into test and train datasets (already split but assigning to meaningful convention)
#If you only have one dataset then split here
x_train, y_train, x_test, y_test = train_images, train_labels_encoded, test_images, test_labels_encoded

# Normalize pixel values to between 0 and 1
#x_train, x_test = x_train / 255.0, x_test / 255.0

###################################################################
# FEATURE EXTRACTOR function
# input shape is (n, x, y, c) - number of images, x, y, and channels
def feature_extractor(dataset):
    image_dataset = pd.DataFrame()
    for image in range(dataset.shape[0]):  #iterate through each file 
        #print(image)
        
        df = pd.DataFrame()  #Temporary data frame to capture information for each loop.
        #Reset dataframe to blank after each loop.
        
        img = dataset[image, :,:]
    ################################################################
    #START ADDING DATA TO THE DATAFRAME
  
                
         #Full image
        #GLCM = greycomatrix(img, [1], [0, np.pi/4, np.pi/2, 3*np.pi/4])
        GLCM = greycomatrix(img, [1], [0])       
        GLCM_Energy = greycoprops(GLCM, 'energy')[0]
        df['Energy'] = GLCM_Energy
        GLCM_corr = greycoprops(GLCM, 'correlation')[0]
        df['Corr'] = GLCM_corr       
        GLCM_diss = greycoprops(GLCM, 'dissimilarity')[0]
        df['Diss_sim'] = GLCM_diss       
        GLCM_hom = greycoprops(GLCM, 'homogeneity')[0]
        df['Homogen'] = GLCM_hom       
        GLCM_contr = greycoprops(GLCM, 'contrast')[0]
        df['Contrast'] = GLCM_contr
        
        #Add more filters as needed
        entropy = shannon_entropy(img)
        df['Entropy'] = entropy

        
        #Append features from current image to the dataset
        image_dataset = image_dataset.append(df)
        
    return image_dataset
####################################################################
#Extract features from training images
image_features = feature_extractor(x_train)
X_for_ML =image_features
# Out:
# /content/drive/MyDrive/Breast Cancer/Final Work/Dataset/Grade_1
# /content/drive/MyDrive/Breast Cancer/Final Work/Dataset/Grade_1/gamma_corr 0.png
# /content/drive/MyDrive/Breast Cancer/Final Work/Dataset/Grade_1/gamma_corr 1.png
# /content/drive/MyDrive/Breast Cancer/Final Work/Dataset/Grade_1/gamma_corr 2.png
# /content/drive/MyDrive/Breast Cancer/Final Work/Dataset/Grade_1/gamma_corr 3.png
# /content/drive/MyDrive/Breast Cancer/Final Work/Dataset/Grade_1/gamma_corr 4.png
# /content/drive/MyDrive/Breast Cancer/Final Work/Dataset/Grade_1/gamma_corr 5.png
# /content/drive/MyDrive/Breast Cancer/Final Work/Dataset/Grade_1/gamma_corr 6.png
# /content/drive/MyDrive/Breast Cancer/Final Work/Dataset/Grade_1/gamma_corr 7.png
# /content/drive/MyDrive/Breast Cancer/Final Work/Dataset/Grade_1/gamma_corr 8.png
# /content/drive/MyDrive/Breast Cancer/Final Work/Dataset/Grade_1/gamma_corr 9.png
# /content/drive/MyDrive/Breast Cancer/Final Work/Dataset/Grade_1/gamma_corr 10.png
# ...

# %%
image_features
# Out:
#       Energy      Corr   Diss_sim   Homogen     Contrast   Entropy
# 0   0.011908  0.620720  21.628263  0.063422   906.431514  7.065441
# 0   0.011206  0.612358  24.397642  0.061247  1223.649243  7.218910
# 0   0.012057  0.527785  22.558416  0.057224  1004.258288  7.023478
# 0   0.011055  0.560059  24.599295  0.056773  1188.507727  7.160994
# 0   0.011541  0.641532  23.989790  0.062903  1145.882647  7.183473
# ..       ...       ...        ...       ...          ...       ...
# 0   0.015679  0.510109  19.904769  0.063327   795.979320  6.704921
# 0   0.008500  0.511263  34.694487  0.044509  2242.354841  7.494151
# 0   0.009139  0.564340  32.804652  0.047431  2082.439061  7.463278
# 0   0.014418  0.521568  22.376121  0.060362  1061.033472  6.799778
# 0   0.011965  0.659731  22.983044  0.065555  1050.091748  7.164155
#
# [317 rows x 6 columns]

# %%
image_features.to_csv('/content/drive/MyDrive/Breast Cancer/Final Work/CSV File/GLCM_Grade_1.csv')

# %% [markdown]
# # **Grade_2**

# %%
SIZE =224
train_images = []
train_labels = [] 
#for directory_path in glob.glob("cell_images/train/*"):
for directory_path in glob.glob("/content/drive/MyDrive/Breast Cancer/Final Work/Dataset/Grade_2"):
    label = directory_path.split("\\")[-1]
    print(label)
    for img_path in glob.glob(os.path.join(directory_path, "*.png")):
        print(img_path)
        img = cv2.imread(img_path, 0) #Reading color images
        img = cv2.resize(img, (SIZE, SIZE)) #Resize images
        train_images.append(img)
        train_labels.append(label)
        
train_images = np.array(train_images)
train_labels = np.array(train_labels)

#Do exactly the same for test/validation images
# test
test_images = []
test_labels = []
#for directory_path in glob.glob("cell_images/test/*"): 
for directory_path in glob.glob("/content/drive/MyDrive/Breast Cancer/Final Work/Dataset/Grade_2"):
    fruit_label = directory_path.split("\\")[-1]
    for img_path in glob.glob(os.path.join(directory_path, "*.png")):
        img = cv2.imread(img_path, 0)
        img = cv2.resize(img, (SIZE, SIZE))
        test_images.append(img)
        test_labels.append(fruit_label)
        
test_images = np.array(test_images)
test_labels = np.array(test_labels)

#Encode labels from text (folder names) to integers.
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
le.fit(test_labels)
test_labels_encoded = le.transform(test_labels)
le.fit(train_labels)
train_labels_encoded = le.transform(train_labels)

#Split data into test and train datasets (already split but assigning to meaningful convention)
#If you only have one dataset then split here
x_train, y_train, x_test, y_test = train_images, train_labels_encoded, test_images, test_labels_encoded

# Normalize pixel values to between 0 and 1
#x_train, x_test = x_train / 255.0, x_test / 255.0

###################################################################
# FEATURE EXTRACTOR function
# input shape is (n, x, y, c) - number of images, x, y, and channels
def feature_extractor(dataset):
    image_dataset = pd.DataFrame()
    for image in range(dataset.shape[0]):  #iterate through each file 
        #print(image)
        
        df = pd.DataFrame()  #Temporary data frame to capture information for each loop.
        #Reset dataframe to blank after each loop.
        
        img = dataset[image, :,:]
    ################################################################
    #START ADDING DATA TO THE DATAFRAME
  
                
         #Full image
        #GLCM = greycomatrix(img, [1], [0, np.pi/4, np.pi/2, 3*np.pi/4])
        GLCM = greycomatrix(img, [1], [0])       
        GLCM_Energy = greycoprops(GLCM, 'energy')[0]
        df['Energy'] = GLCM_Energy
        GLCM_corr = greycoprops(GLCM, 'correlation')[0]
        df['Corr'] = GLCM_corr       
        GLCM_diss = greycoprops(GLCM, 'dissimilarity')[0]
        df['Diss_sim'] = GLCM_diss       
        GLCM_hom = greycoprops(GLCM, 'homogeneity')[0]
        df['Homogen'] = GLCM_hom       
        GLCM_contr = greycoprops(GLCM, 'contrast')[0]
        df['Contrast'] = GLCM_contr
        
        #Add more filters as needed
        entropy = shannon_entropy(img)
        df['Entropy'] = entropy

        
        #Append features from current image to the dataset
        image_dataset = image_dataset.append(df)
        
    return image_dataset
####################################################################
#Extract features from training images
image_features = feature_extractor(x_train)
X_for_ML =image_features
# Out:
# /content/drive/MyDrive/Breast Cancer/Final Work/Dataset/Grade_2
# /content/drive/MyDrive/Breast Cancer/Final Work/Dataset/Grade_2/gamma_corr 0.png
# /content/drive/MyDrive/Breast Cancer/Final Work/Dataset/Grade_2/gamma_corr 1.png
# /content/drive/MyDrive/Breast Cancer/Final Work/Dataset/Grade_2/gamma_corr 2.png
# /content/drive/MyDrive/Breast Cancer/Final Work/Dataset/Grade_2/gamma_corr 3.png
# /content/drive/MyDrive/Breast Cancer/Final Work/Dataset/Grade_2/gamma_corr 4.png
# /content/drive/MyDrive/Breast Cancer/Final Work/Dataset/Grade_2/gamma_corr 5.png
# /content/drive/MyDrive/Breast Cancer/Final Work/Dataset/Grade_2/gamma_corr 6.png
# /content/drive/MyDrive/Breast Cancer/Final Work/Dataset/Grade_2/gamma_corr 7.png
# /content/drive/MyDrive/Breast Cancer/Final Work/Dataset/Grade_2/gamma_corr 8.png
# /content/drive/MyDrive/Breast Cancer/Final Work/Dataset/Grade_2/gamma_corr 9.png
# /content/drive/MyDrive/Breast Cancer/Final Work/Dataset/Grade_2/gamma_corr 10.png
# ...

# %%
image_features
# Out:
#       Energy      Corr   Diss_sim   Homogen     Contrast   Entropy
# 0   0.008095  0.373671  37.547205  0.033853  2453.453515  7.436585
# 0   0.010607  0.500801  24.453996  0.047480  1067.684898  7.060726
# 0   0.011342  0.515079  24.236447  0.057419  1148.293982  7.099754
# 0   0.012916  0.392081  21.898603  0.056000   910.301549  6.750675
# 0   0.012295  0.447214  21.414138  0.057471   857.345792  6.823105
# ..       ...       ...        ...       ...          ...       ...
# 0   0.010328  0.508683  26.743274  0.051838  1343.031951  7.157679
# 0   0.011486  0.440319  24.151085  0.045763  1032.033332  6.905078
# 0   0.041634  0.583186  21.004564  0.130220  1195.494194  6.169587
# 0   0.012321  0.533114  22.407351  0.058935   954.580357  6.933088
# 0   0.011676  0.415681  23.068125  0.049793   946.476397  6.853025
#
# [480 rows x 6 columns]

# %%
image_features.to_csv('/content/drive/MyDrive/Breast Cancer/Final Work/CSV File/GLCM_Grade_2.csv')

# %% [markdown]
# # **Grade_3**

# %%
SIZE =224
train_images = []
train_labels = [] 
#for directory_path in glob.glob("cell_images/train/*"):
for directory_path in glob.glob("/content/drive/MyDrive/Breast Cancer/Final Work/Dataset/Grade_3"):
    label = directory_path.split("\\")[-1]
    print(label)
    for img_path in glob.glob(os.path.join(directory_path, "*.png")):
        print(img_path)
        img = cv2.imread(img_path, 0) #Reading color images
        img = cv2.resize(img, (SIZE, SIZE)) #Resize images
        train_images.append(img)
        train_labels.append(label)
        
train_images = np.array(train_images)
train_labels = np.array(train_labels)

#Do exactly the same for test/validation images
# test
test_images = []
test_labels = []
#for directory_path in glob.glob("cell_images/test/*"): 
for directory_path in glob.glob("/content/drive/MyDrive/Breast Cancer/Final Work/Dataset/Grade_3"):
    fruit_label = directory_path.split("\\")[-1]
    for img_path in glob.glob(os.path.join(directory_path, "*.png")):
        img = cv2.imread(img_path, 0)
        img = cv2.resize(img, (SIZE, SIZE))
        test_images.append(img)
        test_labels.append(fruit_label)
        
test_images = np.array(test_images)
test_labels = np.array(test_labels)

#Encode labels from text (folder names) to integers.
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
le.fit(test_labels)
test_labels_encoded = le.transform(test_labels)
le.fit(train_labels)
train_labels_encoded = le.transform(train_labels)

#Split data into test and train datasets (already split but assigning to meaningful convention)
#If you only have one dataset then split here
x_train, y_train, x_test, y_test = train_images, train_labels_encoded, test_images, test_labels_encoded

# Normalize pixel values to between 0 and 1
#x_train, x_test = x_train / 255.0, x_test / 255.0

###################################################################
# FEATURE EXTRACTOR function
# input shape is (n, x, y, c) - number of images, x, y, and channels
def feature_extractor(dataset):
    image_dataset = pd.DataFrame()
    for image in range(dataset.shape[0]):  #iterate through each file 
        #print(image)
        
        df = pd.DataFrame()  #Temporary data frame to capture information for each loop.
        #Reset dataframe to blank after each loop.
        
        img = dataset[image, :,:]
    ################################################################
    #START ADDING DATA TO THE DATAFRAME
  
                
         #Full image
        #GLCM = greycomatrix(img, [1], [0, np.pi/4, np.pi/2, 3*np.pi/4])
        GLCM = greycomatrix(img, [1], [0])       
        GLCM_Energy = greycoprops(GLCM, 'energy')[0]
        df['Energy'] = GLCM_Energy
        GLCM_corr = greycoprops(GLCM, 'correlation')[0]
        df['Corr'] = GLCM_corr       
        GLCM_diss = greycoprops(GLCM, 'dissimilarity')[0]
        df['Diss_sim'] = GLCM_diss       
        GLCM_hom = greycoprops(GLCM, 'homogeneity')[0]
        df['Homogen'] = GLCM_hom       
        GLCM_contr = greycoprops(GLCM, 'contrast')[0]
        df['Contrast'] = GLCM_contr
        
        #Add more filters as needed
        entropy = shannon_entropy(img)
        df['Entropy'] = entropy

        
        #Append features from current image to the dataset
        image_dataset = image_dataset.append(df)
        
    return image_dataset
####################################################################
#Extract features from training images
image_features = feature_extractor(x_train)
X_for_ML =image_features
# Out:
# /content/drive/MyDrive/Breast Cancer/Final Work/Dataset/Grade_3
# /content/drive/MyDrive/Breast Cancer/Final Work/Dataset/Grade_3/gamma_corr 0.png
# /content/drive/MyDrive/Breast Cancer/Final Work/Dataset/Grade_3/gamma_corr 1.png
# /content/drive/MyDrive/Breast Cancer/Final Work/Dataset/Grade_3/gamma_corr 2.png
# /content/drive/MyDrive/Breast Cancer/Final Work/Dataset/Grade_3/gamma_corr 3.png
# /content/drive/MyDrive/Breast Cancer/Final Work/Dataset/Grade_3/gamma_corr 4.png
# /content/drive/MyDrive/Breast Cancer/Final Work/Dataset/Grade_3/gamma_corr 5.png
# /content/drive/MyDrive/Breast Cancer/Final Work/Dataset/Grade_3/gamma_corr 6.png
# /content/drive/MyDrive/Breast Cancer/Final Work/Dataset/Grade_3/gamma_corr 7.png
# /content/drive/MyDrive/Breast Cancer/Final Work/Dataset/Grade_3/gamma_corr 8.png
# /content/drive/MyDrive/Breast Cancer/Final Work/Dataset/Grade_3/gamma_corr 9.png
# /content/drive/MyDrive/Breast Cancer/Final Work/Dataset/Grade_3/gamma_corr 10.png
# ...

# %%
image_features
# Out:
#       Energy      Corr   Diss_sim   Homogen     Contrast   Entropy
# 0   0.011181  0.489881  23.965127  0.049811  1052.738509  6.982391
# 0   0.010052  0.489319  26.213925  0.047480  1266.210802  7.141338
# 0   0.012230  0.550322  21.027707  0.060557   843.894619  6.962439
# 0   0.014769  0.416863  18.516496  0.061389   621.528267  6.483160
# 0   0.016317  0.662297  16.095812  0.087235   592.114710  6.726612
# ..       ...       ...        ...       ...          ...       ...
# 0   0.010085  0.384528  28.361807  0.040651  1390.755705  7.089084
# 0   0.011151  0.438443  25.290359  0.046607  1141.602418  7.002852
# 0   0.010679  0.350072  27.234045  0.042219  1301.520680  7.011515
# 0   0.009819  0.465099  29.382527  0.042680  1545.753643  7.224030
# 0   0.010305  0.480479  25.749600  0.049949  1226.244114  7.096920
#
# [361 rows x 6 columns]

# %%
image_features.to_csv('/content/drive/MyDrive/Breast Cancer/Final Work/CSV File/GLCM_Grade_3.csv')
